# %%
# !nvidia-smi
# Out:
# Thu Nov 16 17:02:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "exp016" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110683 sha256=e0f53d734a15263c04ca932cd638fc38acbdfa6ce55e25d3d396bda5d06ff9e4
#   Stored in directory: /root/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)
    # EXP_MODEL = os.path.join(OUTPUT_EXP, "model")
    # EXP_FIG = os.path.join(OUTPUT_EXP, "fig")
    # EXP_PREDS = os.path.join(OUTPUT_EXP, "preds")

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab
# Mounted at /content/drive

# %%
# %%time
# tmp fileに直接ダウンロードする
TMP = '/content/tmp'
INPUT = '/content/tmp'
# !mkdir $TMP
files = [
    'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
        #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
        #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
        #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
    'jirkaborovec/tiles-of-cancer-2048px-scale-0-25'
         ]
for f in files:
    # !kaggle datasets download -d $f -p $TMP
    t = f.split('/')[1]
    unzip_file = os.path.join(TMP, f'{t}.zip')
    unzip_file_ = TMP + '/' + t
    INPUT_ = INPUT + '/' + t
    ! unzip $unzip_file -d $unzip_file_
    # !mv $unzip_file_ $INPUT_
    # !rm -rf $unzip_file
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/12902/
4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000170_21-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000180_31-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000181_32-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000182_33-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000183_34-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000184_35-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000185_36-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000186_37-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000187_38-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000188_39-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000189_40-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000190_41-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000191_42-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000192_43-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000193_44-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000194_45-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000195_46-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000196_47-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000197_48-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000202_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000203_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000204_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000205_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000206_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000207_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000208_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000209_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000210_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000211_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000212_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000213_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000214_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000215_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000216_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000217_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000218_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000219_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000220_21-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000231_32-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000232_33-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000233_34-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000234_35-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000235_36-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000236_37-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000237_38-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000238_39-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000239_40-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000240_41-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000241_42-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000242_43-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000243_44-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000244_45-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000245_46-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000246_47-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000247_48-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000248_49-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000249_50-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000252_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000253_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000254_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000255_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000256_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000257_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000258_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000259_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000260_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000261_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000262_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000263_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000264_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000265_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000266_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000267_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000268_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000269_20-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000280_31-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000281_32-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000282_33-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000283_34-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000284_35-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000285_36-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000286_37-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000287_38-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000288_39-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000289_40-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000290_41-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000291_42-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000292_43-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000293_44-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000294_45-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000295_46-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000296_47-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000297_48-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000298_49-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000299_50-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000301_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000302_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000303_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000304_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000305_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000306_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000307_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000308_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000309_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000310_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000311_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000312_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000313_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000314_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000315_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000316_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000317_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000330_31-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000331_32-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000332_33-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000333_34-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000334_35-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000335_36-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000336_37-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000337_38-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000338_39-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000339_40-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000340_41-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000341_42-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000342_43-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000343_44-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000344_45-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000345_46-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000346_47-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000347_48-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000348_49-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000349_50-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000351_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000352_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000353_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000354_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000355_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000356_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000357_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000358_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000359_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000360_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000361_12-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000362_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000363_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000364_15-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000365_16-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000366_17-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000367_18-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000380_31-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000381_32-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000382_33-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000383_34-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000384_35-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000385_36-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000386_37-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000387_38-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000388_39-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000389_40-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000390_41-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000391_42-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000392_43-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000393_44-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000394_45-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000395_46-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000396_47-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000401_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000402_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000403_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000404_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000405_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000406_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000407_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000408_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000409_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000410_11-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000411_12-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000412_13-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000413_14-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000414_15-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000415_16-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/15231/000416_17-9.png

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %%
# df = pd.read_csv('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/train.csv')
# df[df.image_id==int(folders[1].split('/')[-1])].is_tma.values
# from glob import glob
# folders = glob('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/*')
# for f in sorted(folders, key=lambda x: int(x.split('/')[-1]) if x.split('/')[-1]!='train.csv' else 999999)[:-1]:
#     tma=False
#     if df[df.image_id==int(f.split('/')[-1])].is_tma.values[0]:
#         tma=True
#     print(f.split('/')[-1], len(glob(f+'/*png')), tma)

# %% [markdown]
# # Config

# %%
DEBUG = False
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
tile_size = 512
image_size = 512
n_tiles = 4 if DEBUG else 9
batch_size = 2
num_workers = os.cpu_count()
out_dim = 5
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 20
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    # if 4 <= image_id <= 15188:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-1')
    # elif 15209 <= image_id <= 30515:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-2')
    # elif 30539 <= image_id <= 38687:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-3')
    # elif 38849 <= image_id <= 65300:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-4')
    # elif 65371 <= image_id <= 65533:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-5')
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください

class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features, out_dim)
        self.enet.classifier = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
        x = self.myfc(x)
        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
# import joblib
# good_images = joblib.load(os.path.join(INPUT, 'ucbo-clean-images/good_images.pkl'))

# %%
def get_tiles(paths):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)

        # Pillow ImageオブジェクトをNumPy配列に変換
        image_array = np.array(image)
        ret.append(image_array)
    return ret


class PANDADataset(Dataset):
    def __init__(self,
                 df,
                 image_size,
                 n_tiles=n_tiles,
                 tile_mode=0,
                 rand=False,
                 transform=None,
                ):

        self.df = df.reset_index(drop=True)
        self.image_size = image_size
        self.n_tiles = n_tiles
        self.tile_mode = tile_mode
        self.rand = rand
        self.transform = transform

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]
        img_id = row.image_id

        files = os.listdir(row.tile_path)
        tiles = [row.tile_path + f'/{e}' for e in files]
        n_imgs = len(tiles)
        tiles = get_tiles(tiles)


        if self.rand:
            idxes = np.random.choice(list(range(self.n_tiles)), self.n_tiles, replace=False)
        else:
            idxes = list(range(self.n_tiles))

        n_row_tiles = int(np.sqrt(self.n_tiles))
        images = np.zeros((image_size * n_row_tiles, image_size * n_row_tiles, 3))
        for h in range(n_row_tiles):
            for w in range(n_row_tiles):
                i = h * n_row_tiles + w

                # fill all tiles(exp014)
                this_img = tiles[idxes[i%n_imgs]]

                # if len(tiles) > idxes[i]:
                #     this_img = tiles[idxes[i]]
                # else:
                #     this_img = np.ones((self.image_size, self.image_size, 3)).astype(np.uint8) * 255
                this_img = 255 - this_img
                if self.transform is not None:
                    this_img = self.transform(image=this_img)['image']
                h1 = h * image_size
                w1 = w * image_size
                images[h1:h1+image_size, w1:w1+image_size] = this_img

        if self.transform is not None:
            images = self.transform(image=images)['image']
        images = images.astype(np.float32)
        # images /= 255
        images = images.transpose(2, 0, 1)

        # label = np.zeros(out_dim).astype(np.float32)
        # label[l2n[row.label]] = 1.

        #label smoothing(exp006)
        eps = 0.05
        label = np.ones(out_dim).astype(np.float32) * eps/out_dim
        label[l2n[row.label]] += (1. - eps)

        return torch.tensor(images), torch.tensor(label)

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
# dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, transform=transforms_train)
# from pylab import rcParams
# rcParams['figure.figsize'] = 20,10
# for i in range(2):
#     f, axarr = plt.subplots(1,5)
#     for p in range(5):
#         idx = np.random.randint(0, len(dataset_show))
#         img, label = dataset_show[idx]
#         axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
#         axarr[p].set_title(label)

# %% [markdown]
# # Loss

# %%
criterion = nn.BCEWithLogitsLoss()
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
def train_epoch(loader, optimizer):

    model.train()
    train_loss = []
    bar = tqdm(loader)
    for (data, target) in bar:

        data, target = data.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        logits = model(data)
        loss = loss_func(logits, target)
        loss.backward()
        optimizer.step()

        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, target) in tqdm(loader):
            data, target = data.to(device), target.to(device)
            logits = model(data)

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
#     acc = (PREDS == TARGETS).mean() * 100.
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

#     qwk = cohen_kappa_score(PREDS, TARGETS, weights='quadratic')
#     qwk_k = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'karolinska'], df_valid[df_valid['data_provider'] == 'karolinska'].isup_grade.values, weights='quadratic')
#     qwk_r = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'radboud'], df_valid[df_valid['data_provider'] == 'radboud'].isup_grade.values, weights='quadratic')
#     print('qwk', qwk, 'qwk_k', qwk_k, 'qwk_r', qwk_r)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))

# %% [markdown]
# # Run Training

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}'
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
