# %%
# !nvidia-smi
# Out:
# Thu Dec  7 16:45:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "exp039" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

DEBUG = False

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110683 sha256=256f97ead73c936b1aa3ab584545bc8e5fd7a2f6da0101eb897d2c1a34e6511a
#   Stored in directory: /root/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)
    # EXP_MODEL = os.path.join(OUTPUT_EXP, "model")
    # EXP_FIG = os.path.join(OUTPUT_EXP, "fig")
    # EXP_PREDS = os.path.join(OUTPUT_EXP, "preds")

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab
# Mounted at /content/drive

# %%
# %%time
if not DEBUG:
    # tmp fileに直接ダウンロードする
    TMP = '/content/tmp'
    INPUT = '/content/tmp'
    # !mkdir $TMP
    files = [
        'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
            #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
            #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
            #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
        'jirkaborovec/tiles-of-cancer-2048px-scale-0-25'
            ]
    for f in files:
        # !kaggle datasets download -d $f -p $TMP
        t = f.split('/')[1]
        unzip_file = os.path.join(TMP, f'{t}.zip')
        unzip_file_ = TMP + '/' + t
        INPUT_ = INPUT + '/' + t
        ! unzip $unzip_file -d $unzip_file_
        # !mv $unzip_file_ $INPUT_
        # !rm -rf $unzip_file
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/
16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000079_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000080_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000081_19-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000082_20-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000083_21-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000084_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000085_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000086_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000087_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000088_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000089_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000090_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000091_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000092_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000093_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000094_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000095_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000096_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000097_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000098_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000099_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000100_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000101_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000102_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000103_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000105_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000106_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000107_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000108_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000109_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000110_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000111_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000112_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000113_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000114_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000115_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000116_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000117_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000118_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000119_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000120_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000121_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000122_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000123_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000124_20-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000126_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000127_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000128_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000129_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000130_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000131_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000132_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000133_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000134_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000135_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000136_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000137_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000138_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000139_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000140_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000141_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000142_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000143_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000144_19-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000148_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000149_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000150_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000151_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000152_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000153_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000154_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000155_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000156_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000157_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000169_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000170_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000171_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000172_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000190_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/9697/000191_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000006_7-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000011_12-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000012_13-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000013_14-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000019_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000020_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000021_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000022_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000023_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000026_11-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000027_12-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000028_13-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000029_14-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000034_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000035_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000036_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000037_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000038_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000039_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000041_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000042_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000043_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000044_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000045_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000046_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000047_16-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000048_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000049_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000050_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000051_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000052_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000053_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000054_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000055_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000056_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000057_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000058_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000059_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000060_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000061_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000062_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000063_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000064_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000065_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000066_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000067_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000068_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000069_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000070_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000071_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000072_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000073_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000074_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000075_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000076_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000077_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000078_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000079_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000080_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000081_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000082_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000083_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000084_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000085_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000086_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000087_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000088_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000089_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000090_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000091_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000092_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000093_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000094_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000095_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000096_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000097_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000098_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000099_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000100_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000101_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000102_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000103_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000104_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000105_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000106_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000107_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000108_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000109_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000110_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000116_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000117_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000118_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000119_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000120_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000121_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000122_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000123_12-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000124_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000125_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000134_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000135_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000136_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000137_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000138_11-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000139_12-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000151_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000152_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000153_10-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/970/000154_11-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/train.csv
# CPU times: user 14.1 s, sys: 1.94 s, total: 16.1 s
# Wall time: 20min 33s

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm
# Out:
# Collecting git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
#   Cloning https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to /tmp/pip-req-build-psv16pkk
#   Running command git clone --filter=blob:none --quiet https://github.com/ildoonet/pytorch-gradual-warmup-lr.git /tmp/pip-req-build-psv16pkk
#   Resolved https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to commit 6b5e8953a80aef5b324104dc0c2e9b8c34d622bd
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: warmup-scheduler
#   Building wheel for warmup-scheduler (setup.py) ... done
#   Created wheel for warmup-scheduler: filename=warmup_scheduler-0.3.2-py3-none-any.whl size=3863 sha256=0e7e4a37c95920216f1041569403459da6032b8d4af5bef3f2187fd3b67db9e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zbg9br7m/wheels/49/78/e6/9168d5844935482a171c7880a0626fa1c6c412b55666635f59
# Successfully built warmup-scheduler
# Installing collected packages: warmup-scheduler
# Successfully installed warmup-scheduler-0.3.2
# Collecting timm
#   Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.9.12

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %%
# df = pd.read_csv('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/train.csv')
# df[df.image_id==int(folders[1].split('/')[-1])].is_tma.values
# from glob import glob
# folders = glob('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/*')
# for f in sorted(folders, key=lambda x: int(x.split('/')[-1]) if x.split('/')[-1]!='train.csv' else 999999)[:-1]:
#     tma=False
#     if df[df.image_id==int(f.split('/')[-1])].is_tma.values[0]:
#         tma=True
#     print(f.split('/')[-1], len(glob(f+'/*png')), tma)

# %% [markdown]
# # Config

# %%
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
# tile_size = 512
image_size = 256
n_tiles = 4 if DEBUG else 16
batch_size = 2
num_workers = os.cpu_count()
out_dim = 5
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 20
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()
# Out:
# /content/tmp/tiles-of-cancer-2048px-scale-0-25/train_images

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    # if 4 <= image_id <= 15188:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-1')
    # elif 15209 <= image_id <= 30515:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-2')
    # elif 30539 <= image_id <= 38687:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-3')
    # elif 38849 <= image_id <= 65300:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-4')
    # elif 65371 <= image_id <= 65533:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-5')
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください

class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features, out_dim)
        self.enet.classifier = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
        x = self.myfc(x)
        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
import joblib
good_images = joblib.load(os.path.join(OUTPUT, 'bw_checker/good_images.pkl'))

# %%
def get_tiles(paths):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)

        # Pillow ImageオブジェクトをNumPy配列に変換
        image_array = np.array(image)
        ret.append(image_array)
    return ret


class PANDADataset(Dataset):
    def __init__(self,
                 df,
                 image_size,
                 n_tiles=n_tiles,
                 tile_mode=0,
                 rand=False,
                 transform=None,
                ):

        self.df = df.reset_index(drop=True)
        self.image_size = image_size
        self.n_tiles = n_tiles
        self.tile_mode = tile_mode
        self.rand = rand
        self.transform = transform

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]
        img_id = row.image_id


        try:
            tiles = good_images[img_id]
        except:
            files = os.listdir(row.tile_path)
            tiles = [row.tile_path + f'/{e}' for e in files]
        if DEBUG:
            tiles = [t.replace('/content/tmp', INPUT) for t in tiles]
        n_imgs = len(tiles)
        tiles = get_tiles(tiles)


        if self.rand:
            idxes = np.random.choice(list(range(self.n_tiles)), self.n_tiles, replace=False)
        else:
            idxes = list(range(self.n_tiles))

        n_row_tiles = int(np.sqrt(self.n_tiles))
        images = np.zeros((self.image_size * n_row_tiles, self.image_size * n_row_tiles, 3))
        for h in range(n_row_tiles):
            for w in range(n_row_tiles):
                i = h * n_row_tiles + w

                # fill all tiles(exp014)
                try:
                    this_img = tiles[idxes[i%n_imgs]]
                    this_img = PIL.Image.fromarray(this_img).resize((self.image_size, self.image_size))
                    this_img = np.array(this_img)
                except:
                    this_img = np.ones((self.image_size, self.image_size, 3)).astype(np.uint8) * 255

                this_img = 255 - this_img
                if self.transform is not None:
                    this_img = self.transform(image=this_img)['image']
                h1 = h * self.image_size
                w1 = w * self.image_size
                images[h1:h1+self.image_size, w1:w1+self.image_size] = this_img

        # if self.transform is not None:
        #     images = self.transform(image=images)['image']
        images = images.astype(np.float32)
        # images /= 255
        images = images.transpose(2, 0, 1)

        # default label
        label = np.zeros(out_dim).astype(np.float32)
        label[l2n[row.label]] = 1.

        #label smoothing(exp006)
        # eps = 0.05
        # label = np.ones(out_dim).astype(np.float32) * eps/out_dim
        # label[l2n[row.label]] += (1. - eps)

        return torch.tensor(images), torch.tensor(label)

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, transform=None)
from pylab import rcParams
rcParams['figure.figsize'] = 20,10
for i in range(2):
    f, axarr = plt.subplots(1,5)
    for p in range(5):
        idx = np.random.randint(0, len(dataset_show))
        img, label = dataset_show[idx]
        axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
        axarr[p].set_title(label)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Loss

# %%
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
pos_weight = torch.tensor([1.0, 3.0, 3.0, 3.0, 1.0], dtype=torch.float32)
pos_weight = pos_weight.to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
def train_epoch(loader, optimizer):

    model.train()
    train_loss = []
    bar = tqdm(loader)
    for (data, target) in bar:

        data, target = data.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        logits = model(data)
        loss = loss_func(logits, target)
        loss.backward()
        optimizer.step()

        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, target) in tqdm(loader):
            data, target = data.to(device), target.to(device)
            logits = model(data)

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
#     acc = (PREDS == TARGETS).mean() * 100.
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

#     qwk = cohen_kappa_score(PREDS, TARGETS, weights='quadratic')
#     qwk_k = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'karolinska'], df_valid[df_valid['data_provider'] == 'karolinska'].isup_grade.values, weights='quadratic')
#     qwk_r = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'radboud'], df_valid[df_valid['data_provider'] == 'radboud'].isup_grade.values, weights='quadratic')
#     print('qwk', qwk, 'qwk_k', qwk_k, 'qwk_r', qwk_r)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))
# Out:
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# 430 108

# %% [markdown]
# # Run Training

# %%
def mymetric(df):
    cols = df['label'].unique().tolist()
    recalls = dict()
    for col in cols:
        df_ = df.query('label==@col')
        recalls[col] = (df_['label']==df_['pred']).sum()/df_.shape[0]
    score = 0
    for k, v in recalls.items():
        score += v
    score /= len(cols)
    return score, recalls

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)
    df_valid['pred'] = oof_preds.argmax(1)
    df_valid['pred'] = df_valid['pred'].map(n2l)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}, '
    content += str(mymetric(df_valid))
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
# Out:
# Thu Dec  7 17:06:54 2023 Epoch: 1
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.33044444444444443
# Thu Dec  7 17:25:56 2023 Epoch 1, lr: 0.0000300, train loss: 0.75790, val loss: 0.65654, balanced accuracy: 0.33044, (0.33044444444444443, {'HGSC': 0.9111111111111111, 'CC': 0.35, 'EC': 0.28, 'MC': 0.1111111111111111, 'LGSC': 0.0})
# score2 (0.000000 --> 0.330444).  Saving model ...
# Thu Dec  7 17:25:57 2023 Epoch: 2
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.39533333333333337
# Thu Dec  7 17:44:52 2023 Epoch 2, lr: 0.0003000, train loss: 0.66769, val loss: 0.63988, balanced accuracy: 0.39533, (0.39533333333333337, {'HGSC': 0.7111111111111111, 'CC': 0.35, 'EC': 0.36, 'MC': 0.0, 'LGSC': 0.5555555555555556})
# score2 (0.330444 --> 0.395333).  Saving model ...
# Thu Dec  7 17:44:52 2023 Epoch: 3
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.42866666666666664
# Thu Dec  7 18:03:43 2023 Epoch 3, lr: 0.0000300, train loss: 0.59929, val loss: 0.50836, balanced accuracy: 0.42867, (0.4286666666666667, {'HGSC': 0.8222222222222222, 'CC': 0.65, 'EC': 0.56, 'MC': 0.0, 'LGSC': 0.1111111111111111})
# score2 (0.395333 --> 0.428667).  Saving model ...
# Thu Dec  7 18:03:43 2023 Epoch: 4
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.5564444444444445
# Thu Dec  7 18:22:37 2023 Epoch 4, lr: 0.0002919, train loss: 0.62293, val loss: 0.54585, balanced accuracy: 0.55644, (0.5564444444444445, {'HGSC': 0.8666666666666667, 'CC': 0.8, 'EC': 0.56, 'MC': 0.3333333333333333, 'LGSC': 0.2222222222222222})
# score2 (0.428667 --> 0.556444).  Saving model ...
# Thu Dec  7 18:22:37 2023 Epoch: 5
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.6926666666666667
# Thu Dec  7 21:34:22 2023 Epoch 14, lr: 0.0000897, train loss: 0.26055, val loss: 0.52351, balanced accuracy: 0.69267, (0.6926666666666668, {'HGSC': 0.6888888888888889, 'CC': 0.65, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# Thu Dec  7 21:34:22 2023 Epoch: 15
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.7582222222222221
# Thu Dec  7 21:54:13 2023 Epoch 15, lr: 0.0000680, train loss: 0.22428, val loss: 0.44270, balanced accuracy: 0.75822, (0.7582222222222221, {'HGSC': 0.7555555555555555, 'CC': 0.8, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# score2 (0.754667 --> 0.758222).  Saving model ...
# Thu Dec  7 21:54:13 2023 Epoch: 16
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.7573333333333333
# Thu Dec  7 22:13:28 2023 Epoch 16, lr: 0.0000484, train loss: 0.21246, val loss: 0.48174, balanced accuracy: 0.75733, (0.7573333333333332, {'HGSC': 0.7111111111111111, 'CC': 0.8, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# Thu Dec  7 22:13:28 2023 Epoch: 17
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.7564444444444444
# Thu Dec  7 22:32:31 2023 Epoch 17, lr: 0.0000316, train loss: 0.18059, val loss: 0.46448, balanced accuracy: 0.75644, (0.7564444444444445, {'HGSC': 0.7777777777777778, 'CC': 0.8, 'EC': 0.76, 'MC': 0.7777777777777778, 'LGSC': 0.6666666666666666})
# Thu Dec  7 22:32:31 2023 Epoch: 18
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.7626666666666666
# Thu Dec  7 22:51:36 2023 Epoch 18, lr: 0.0000181, train loss: 0.17598, val loss: 0.45172, balanced accuracy: 0.76267, (0.7626666666666667, {'HGSC': 0.7777777777777778, 'CC': 0.8, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# score2 (0.758222 --> 0.762667).  Saving model ...
# Thu Dec  7 22:51:36 2023 Epoch: 19
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.7617777777777778
# Thu Dec  7 23:10:46 2023 Epoch 19, lr: 0.0000081, train loss: 0.16082, val loss: 0.49752, balanced accuracy: 0.76178, (0.7617777777777777, {'HGSC': 0.7333333333333333, 'CC': 0.8, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# Thu Dec  7 23:10:46 2023 Epoch: 20
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# 0.744
# Thu Dec  7 23:29:45 2023 Epoch 20, lr: 0.0000020, train loss: 0.13608, val loss: 0.46019, balanced accuracy: 0.74400, (0.744, {'HGSC': 0.7555555555555555, 'CC': 0.8, 'EC': 0.72, 'MC': 0.7777777777777778, 'LGSC': 0.6666666666666666})
# comp metric max 0.7626666666666666
# CPU times: user 14min 39s, sys: 1min 1s, total: 15min 40s
# Wall time: 6h 22min 51s
