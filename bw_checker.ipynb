# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "bw_checker" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

DEBUG = False

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Using cached kaggle-1.5.16-py3-none-any.whl
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab

# %%
# %%time
if not DEBUG:
    # tmp fileに直接ダウンロードする
    TMP = '/content/tmp'
    INPUT = '/content/tmp'
    # !mkdir $TMP
    files = [
        'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
            #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
            #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
            #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
        'jirkaborovec/tiles-of-cancer-2048px-scale-0-25'
            ]
    for f in files:
        # !kaggle datasets download -d $f -p $TMP
        t = f.split('/')[1]
        unzip_file = os.path.join(TMP, f'{t}.zip')
        unzip_file_ = TMP + '/' + t
        INPUT_ = INPUT + '/' + t
        ! unzip $unzip_file -d $unzip_file_
        # !mv $unzip_file_ $INPUT_
        # !rm -rf $unzip_file
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000474_13-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000475_14-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000476_15-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000477_16-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000478_17-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000486_25-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000487_26-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000488_27-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000489_28-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000490_29-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000491_30-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000492_31-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000493_32-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000494_33-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000495_34-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000496_35-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000497_36-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000498_37-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000499_38-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000500_39-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000501_40-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000505_2-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000506_3-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000507_4-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000508_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000509_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000510_7-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000511_8-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000512_9-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000513_10-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000514_11-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000515_12-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000516_13-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000517_14-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000518_15-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000519_16-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000527_24-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000528_25-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000529_26-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000530_27-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000531_28-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000532_29-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000533_30-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000534_31-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000535_32-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000536_33-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000537_34-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000538_35-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000539_36-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000540_37-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000541_38-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000542_39-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000543_40-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000546_1-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000547_2-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000548_3-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000549_4-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000550_5-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000551_6-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000552_7-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000553_8-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000554_9-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000555_10-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000556_11-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000557_12-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000558_13-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000559_14-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000560_15-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000561_16-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000562_17-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000569_24-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000570_25-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000571_26-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000572_27-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000573_28-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000574_29-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000575_30-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000576_31-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000577_32-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000578_33-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000579_34-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000580_35-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000581_36-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000582_37-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000583_38-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000584_39-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000585_40-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000588_1-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000589_2-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000590_3-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000591_4-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000592_5-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000593_6-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000594_7-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000595_8-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000596_9-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000597_10-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000598_11-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000599_12-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000600_13-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000601_14-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000602_15-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000603_16-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000604_17-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000611_24-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000612_25-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000613_26-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000614_27-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000615_28-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000616_29-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000617_30-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000618_31-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000619_32-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000620_33-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000621_34-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000622_35-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000623_36-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000624_37-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000625_38-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000626_39-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000627_40-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000630_1-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000631_2-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000632_3-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000633_4-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000634_5-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000635_6-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000636_7-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000637_8-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000638_9-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000639_10-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000640_11-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000641_12-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000642_13-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000643_14-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000644_15-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000645_16-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000646_17-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000647_18-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000653_24-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000654_25-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000655_26-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000656_27-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000657_28-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000658_29-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000659_30-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000660_31-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000661_32-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000662_33-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000663_34-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000664_35-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000665_36-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000666_37-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000667_38-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000668_39-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000669_40-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000672_1-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000673_2-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000674_3-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000675_4-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000676_5-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000677_6-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000678_7-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000679_8-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000680_9-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000681_10-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000682_11-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000683_12-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000684_13-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000685_14-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000686_15-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000687_16-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000688_17-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000689_18-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000695_24-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000696_25-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000697_26-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000698_27-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000699_28-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000700_29-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000701_30-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000702_31-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000703_32-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000704_33-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000705_34-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000706_35-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000707_36-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000708_37-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000709_38-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000710_39-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000711_40-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000714_1-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000715_2-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000716_3-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000717_4-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000718_5-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000719_6-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000720_7-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000721_8-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000722_9-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000723_10-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000724_11-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000725_12-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000726_13-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000727_14-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000728_15-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000729_16-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000730_17-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000731_18-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000738_25-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000739_26-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000740_27-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000741_28-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000742_29-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000743_30-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000744_31-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000745_32-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000746_33-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000747_34-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000748_35-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000749_36-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000750_37-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000751_38-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000752_39-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000753_40-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000754_41-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000757_2-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000758_3-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000759_4-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000760_5-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000761_6-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000762_7-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000763_8-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000764_9-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000765_10-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000766_11-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000767_12-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000768_13-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000769_14-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000770_15-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000771_16-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000772_17-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000773_18-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000780_25-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000781_26-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000782_27-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000783_28-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000784_29-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000785_30-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000786_31-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000787_32-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000788_33-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000789_34-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000790_35-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000791_36-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000792_37-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000793_38-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000794_39-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000795_40-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000796_41-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000800_3-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000801_4-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000802_5-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000803_6-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000804_7-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000805_8-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000806_9-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000807_10-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000808_11-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000809_12-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000810_13-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000811_14-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000812_15-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000813_16-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000814_17-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000815_18-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000823_26-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000824_27-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000825_28-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000826_29-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000827_30-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000828_31-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000829_32-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000830_33-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000831_34-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000832_35-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000833_36-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000834_37-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000835_38-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000836_39-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000837_40-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000838_41-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000842_3-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000843_4-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000844_5-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000845_6-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000846_7-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000847_8-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000848_9-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000849_10-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000850_11-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000851_12-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000852_13-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000853_14-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000854_15-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000855_16-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000856_17-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000865_26-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000866_27-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000867_28-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000868_29-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000869_30-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000870_31-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000871_32-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000872_33-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000873_34-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000874_35-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000875_36-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000876_37-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000877_38-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000878_39-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000879_40-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000880_41-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000884_3-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000885_4-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000886_5-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000887_6-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000888_7-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000889_8-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000890_9-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000891_10-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000892_11-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000893_12-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000894_13-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000895_14-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000896_15-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000908_27-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000909_28-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000910_29-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000911_30-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000912_31-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000913_32-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000914_33-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000915_34-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000916_35-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000917_36-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000918_37-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000919_38-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000920_39-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000927_4-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000928_5-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000929_6-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000930_7-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000931_8-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000932_9-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000933_10-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000934_11-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000935_12-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000936_13-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000937_14-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000952_29-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000953_30-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000954_31-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000955_32-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000956_33-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000957_34-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000958_35-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000959_36-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000972_7-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000973_8-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000974_9-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000975_10-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000976_11-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000994_29-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51346/000995_30-24.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000015_16-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000016_17-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000017_18-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000018_19-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000035_14-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000036_15-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000037_16-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000038_17-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000039_18-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000040_19-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000055_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000056_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000057_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000058_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000059_16-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000060_17-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000061_18-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000062_19-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000063_20-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000074_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000075_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000076_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000077_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000078_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000079_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000080_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000081_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000082_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000083_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000084_19-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000085_20-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000093_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000094_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000095_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000096_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000097_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000098_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000099_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000100_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000101_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000102_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000103_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000104_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000105_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000106_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000107_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000113_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000114_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000115_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000116_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000117_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000118_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000119_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000120_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000121_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000122_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000123_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000124_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000125_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000126_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000127_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000128_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000129_20-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000130_21-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000132_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000133_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000134_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000135_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000136_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000137_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000138_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000139_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000140_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000141_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000142_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000143_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000144_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000145_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000146_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000147_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000148_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000149_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000150_19-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000151_20-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000152_21-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000154_1-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000155_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000156_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000157_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000158_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000159_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000160_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000161_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000162_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000163_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000164_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000165_12-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000166_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000167_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000168_15-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000169_16-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000170_17-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000171_18-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000172_19-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000173_20-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000174_21-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000175_22-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000177_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000178_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000179_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000180_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000181_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000182_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000183_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000184_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000185_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000186_11-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000187_12-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000188_13-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000189_14-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000190_15-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000191_16-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000192_17-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000193_18-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000194_19-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000195_20-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000196_21-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000197_22-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000199_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000200_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000201_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000202_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000203_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000204_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000205_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000206_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000207_10-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000208_11-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000209_12-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000210_13-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000211_14-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000212_15-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000213_16-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000214_17-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000215_18-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000216_19-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000217_20-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000218_21-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000219_22-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000221_2-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000222_3-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000223_4-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000224_5-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000225_6-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000226_7-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000227_8-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000228_9-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000229_10-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000230_11-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000231_12-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000232_13-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000233_14-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000234_15-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000235_16-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000236_17-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000237_18-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000238_19-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000239_20-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000240_21-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000244_3-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000245_4-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000246_5-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000247_6-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000248_7-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000249_8-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000250_9-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000251_10-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000252_11-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000253_12-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000254_13-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000255_14-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000256_15-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000257_16-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000258_17-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000259_18-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000260_19-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000261_20-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000267_4-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000268_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000269_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000270_7-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/51499/000271_8-13.png
# ...
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000440_21-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000441_22-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000442_23-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000443_24-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000444_25-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000445_26-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000446_27-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000447_28-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000448_29-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000450_1-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000451_2-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000452_3-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000453_4-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000454_5-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000455_6-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000456_7-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000457_8-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000458_9-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000459_10-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000460_11-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000461_12-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000462_13-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000463_14-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000464_15-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000465_16-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000466_17-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000467_18-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000468_19-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000469_20-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000470_21-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000471_22-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000472_23-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000473_24-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000474_25-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000475_26-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000476_27-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000477_28-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000478_29-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000480_1-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000481_2-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000482_3-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000483_4-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000484_5-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000485_6-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000486_7-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000487_8-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000488_9-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000489_10-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000490_11-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000491_12-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000492_13-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000493_14-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000494_15-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000495_16-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000496_17-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000497_18-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000498_19-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000499_20-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000500_21-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000501_22-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000502_23-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000503_24-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000504_25-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000505_26-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000506_27-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000507_28-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000508_29-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000511_2-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000512_3-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000513_4-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000514_5-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000515_6-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000516_7-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000517_8-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000518_9-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000519_10-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000520_11-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000521_12-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000522_13-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000523_14-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000524_15-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000525_16-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000526_17-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000527_18-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000528_19-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000529_20-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000530_21-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000531_22-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000532_23-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000533_24-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000534_25-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000535_26-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000536_27-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000537_28-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000538_29-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000541_2-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000542_3-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000543_4-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000544_5-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000545_6-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000546_7-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000547_8-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000548_9-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000549_10-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000550_11-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000551_12-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000552_13-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000553_14-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000556_17-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000557_18-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000558_19-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000559_20-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000560_21-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000561_22-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000562_23-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000563_24-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000564_25-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000565_26-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000567_28-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000572_3-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000573_4-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000574_5-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000575_6-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000576_7-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000577_8-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000578_9-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000579_10-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000581_12-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000582_13-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000583_14-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000587_18-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000588_19-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000589_20-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000590_21-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000591_22-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000592_23-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000593_24-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000594_25-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000595_26-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000604_5-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000608_9-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000618_19-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000619_20-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000620_21-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000621_22-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000622_23-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000623_24-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000649_20-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000650_21-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000651_22-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52846/000652_23-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000022_23-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000023_24-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000024_25-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000025_26-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000026_27-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000027_28-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000031_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000032_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000033_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000034_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000035_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000050_22-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000051_23-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000052_24-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000053_25-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000054_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000055_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000056_28-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000057_29-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000059_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000060_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000061_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000062_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000063_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000064_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000065_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000078_21-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000079_22-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000080_23-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000081_24-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000082_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000083_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000084_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000085_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000086_29-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000087_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000088_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/52931/000089_3-4.png

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %% [markdown]
# # Config

# %%
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
tile_size = 512
image_size = 512
n_tiles = 4 if DEBUG else 9
batch_size = 2
num_workers = os.cpu_count()
out_dim = 6
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 20
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください

class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features, out_dim)
        self.enet.classifier = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
        x = self.myfc(x)
        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
# def get_tiles(paths):
#     ret = []
#     for path in paths:
#         # PNGファイルを読み込み
#         image = PIL.Image.open(path)

#         # Pillow ImageオブジェクトをNumPy配列に変換
#         image_array = np.array(image)
#         ret.append(image_array)
#     return ret

# def check_bw(image):
#     black = (image.mean(-1)/256 == 0).sum()/256**2
#     white = (image.mean(-1)/256 > 0.92).sum()/256**2
#     return black, white

def check_bw(image):
    tile_size = image.shape[0]
    black = (image.mean(-1)/255 == 0).sum()/tile_size**2
    white = (image.mean(-1)/255 > 0.92).sum()/tile_size**2
    return black, white

def get_tiles(paths, img_id):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)
        # display(image)
        image = np.array(image)
        black, white = check_bw(image)
        # print(black, white)
        if ((black < 0.25) and (white < 0.4) and (black+white < 0.6)) or (df_train.loc[df_train.image_id==img_id, 'is_tma'].values[0]):
            ret.append(path)
    return ret

# %%
good_images = dict()
for e, row in tqdm(df_train.iterrows(), total=df_train.shape[0]):
    # row = self.df.iloc[index]
    img_id = row.image_id

    files = os.listdir(row.tile_path)
    tiles = [row.tile_path + f'/{e}' for e in files]
    good_images[img_id] = get_tiles(tiles, img_id)

# %%
import joblib
joblib.dump(good_images, os.path.join(OUTPUT_EXP, 'good_images.pkl'))

# %%
raise Exception

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, False, transform=transforms_train)
from pylab import rcParams
rcParams['figure.figsize'] = 20,10
for i in range(2):
    f, axarr = plt.subplots(1,5)
    for p in range(5):
        idx = np.random.randint(0, len(dataset_show))
        img, label = dataset_show[idx]
        img = np.clip(img, 0, 1)
        axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
        axarr[p].set_title(label)

# %% [markdown]
# # Loss

# %%
criterion = nn.BCEWithLogitsLoss()
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
def train_epoch(loader, optimizer):

    model.train()
    train_loss = []
    bar = tqdm(loader)
    for (data, target) in bar:

        data, target = data.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        logits = model(data)
        loss = loss_func(logits, target)
        loss.backward()
        optimizer.step()

        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, target) in tqdm(loader):
            data, target = data.to(device), target.to(device)
            logits = model(data)

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
#     acc = (PREDS == TARGETS).mean() * 100.
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

#     qwk = cohen_kappa_score(PREDS, TARGETS, weights='quadratic')
#     qwk_k = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'karolinska'], df_valid[df_valid['data_provider'] == 'karolinska'].isup_grade.values, weights='quadratic')
#     qwk_r = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'radboud'], df_valid[df_valid['data_provider'] == 'radboud'].isup_grade.values, weights='quadratic')
#     print('qwk', qwk, 'qwk_k', qwk_k, 'qwk_r', qwk_r)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))

# %% [markdown]
# # Run Training

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}'
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
