# %%
# !nvidia-smi
# Out:
# Thu Dec 14 15:20:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "exp052" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

DEBUG = False

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110683 sha256=65d24f89df84757483f2ccff240fc19363533d7d82f58c2d62ac7fd9a851dfc9
#   Stored in directory: /root/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)
    # EXP_MODEL = os.path.join(OUTPUT_EXP, "model")
    # EXP_FIG = os.path.join(OUTPUT_EXP, "fig")
    # EXP_PREDS = os.path.join(OUTPUT_EXP, "preds")

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab
# Mounted at /content/drive

# %%
# %%time
if not DEBUG:
    # tmp fileに直接ダウンロードする
    TMP = '/content/tmp'
    INPUT = '/content/tmp'
    # !mkdir $TMP
    files = [
        'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
            #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
            #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
            #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
        'jirkaborovec/tiles-of-cancer-2048px-scale-0-25'
            ]
    for f in files:
        # !kaggle datasets download -d $f -p $TMP
        t = f.split('/')[1]
        unzip_file = os.path.join(TMP, f'{t}.zip')
        unzip_file_ = TMP + '/' + t
        INPUT_ = INPUT + '/' + t
        ! unzip $unzip_file -d $unzip_file_
        # !mv $unzip_file_ $INPUT_
        # !rm -rf $unzip_file
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000354_25-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000355_26-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000356_27-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000357_28-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000358_29-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000359_30-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000360_31-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000365_3-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000366_4-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000367_5-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000368_6-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000369_7-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000370_8-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000371_9-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000372_10-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000373_11-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000374_12-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000375_13-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000376_14-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000377_15-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000378_16-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000379_17-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000380_18-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000381_19-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000382_20-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000383_21-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000384_22-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000385_23-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000386_24-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000387_25-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000388_26-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000389_27-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000390_28-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000391_29-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000392_30-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000393_31-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000394_32-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000398_3-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000399_4-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000400_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000401_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000402_7-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000403_8-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000404_9-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000405_10-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000406_11-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000407_12-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000408_13-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000409_14-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000410_15-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000411_16-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000412_17-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000413_18-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000414_19-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000415_20-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000416_21-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000417_22-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000418_23-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000419_24-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000420_25-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000421_26-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000422_27-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000423_28-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000424_29-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000425_30-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000426_31-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000427_32-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000428_33-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000430_2-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000431_3-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000432_4-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000433_5-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000434_6-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000435_7-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000436_8-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000437_9-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000438_10-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000439_11-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000440_12-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000441_13-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000442_14-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000443_15-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000444_16-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000445_17-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000446_18-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000447_19-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000448_20-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000449_21-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000450_22-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000451_23-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000452_24-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000453_25-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000454_26-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000455_27-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000456_28-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000457_29-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000458_30-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000459_31-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000460_32-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000461_33-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000463_2-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000464_3-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000465_4-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000466_5-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000467_6-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000468_7-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000469_8-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000470_9-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000471_10-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000472_11-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000473_12-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000474_13-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000475_14-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000476_15-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000477_16-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000478_17-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000479_18-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000480_19-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000481_20-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000482_21-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000483_22-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000484_23-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000485_24-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000486_25-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000487_26-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000488_27-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000489_28-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000490_29-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000491_30-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000492_31-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000493_32-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000494_33-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000495_1-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000496_2-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000497_3-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000498_4-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000499_5-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000500_6-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000501_7-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000502_8-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000503_9-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000504_10-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000505_11-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000506_12-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000507_13-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000508_14-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000509_15-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000510_16-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000511_17-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000512_18-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000513_19-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000514_20-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000515_21-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000516_22-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000517_23-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000518_24-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000519_25-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000520_26-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000521_27-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000522_28-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000523_29-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000524_30-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000525_31-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000526_32-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000528_1-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000529_2-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000530_3-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000531_4-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000532_5-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000533_6-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000534_7-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000535_8-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000536_9-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000537_10-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000538_11-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000539_12-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000540_13-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000541_14-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000542_15-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000543_16-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000544_17-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000545_18-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000546_19-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000547_20-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000548_21-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000549_22-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000550_23-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000551_24-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000552_25-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000553_26-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000554_27-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000555_28-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000556_29-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000561_1-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000562_2-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000563_3-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000564_4-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000565_5-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000566_6-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000567_7-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000568_8-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000569_9-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000570_10-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000571_11-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000572_12-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000573_13-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000574_14-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000575_15-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000576_16-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000577_17-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000578_18-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000579_19-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000580_20-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000581_21-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000582_22-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000583_23-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000584_24-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000585_25-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000586_26-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000587_27-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000588_28-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000594_1-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000595_2-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000596_3-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000597_4-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000598_5-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000599_6-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000600_7-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000601_8-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000602_9-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000603_10-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000604_11-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000605_12-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000606_13-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000607_14-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000608_15-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000609_16-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000610_17-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000611_18-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000612_19-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000613_20-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000614_21-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000615_22-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000616_23-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000617_24-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000618_25-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000619_26-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000620_27-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000621_28-19.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000627_1-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000628_2-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000629_3-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000630_4-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000631_5-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000632_6-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000633_7-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000634_8-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000635_9-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000636_10-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000637_11-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000638_12-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000639_13-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000640_14-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000641_15-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000642_16-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000643_17-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000644_18-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000645_19-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000646_20-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000647_21-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000648_22-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000649_23-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000650_24-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000651_25-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000652_26-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000653_27-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000654_28-20.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000661_2-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000662_3-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000663_4-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000664_5-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000665_6-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000666_7-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000667_8-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000668_9-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000669_10-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000670_11-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000671_12-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000672_13-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000673_14-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000674_15-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000675_16-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000676_17-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000677_18-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000678_19-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000679_20-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000680_21-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000681_22-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000682_23-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000683_24-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000684_25-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000685_26-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000686_27-21.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000696_4-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000697_5-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000698_6-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000699_7-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000700_8-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000701_9-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000702_10-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000703_11-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000704_12-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000705_13-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000706_14-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000707_15-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000708_16-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000709_17-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000710_18-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000711_19-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000712_20-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000713_21-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000717_25-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000718_26-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000719_27-22.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000730_5-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000731_6-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000732_7-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000733_8-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000734_9-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31297/000735_10-23.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000000_1-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000001_2-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000009_10-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000012_1-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000013_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000014_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000015_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000016_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000017_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000018_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000019_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000020_9-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000021_10-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000024_1-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000025_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000026_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000027_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000028_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000029_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000030_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000031_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000032_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000033_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000034_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000036_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000037_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000038_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000039_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000040_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000041_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000042_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000043_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000044_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000045_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000046_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000047_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000048_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000049_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000050_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000051_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000052_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000053_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000054_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000055_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000056_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000057_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000058_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000061_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000062_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000063_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000064_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000065_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000066_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000067_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000068_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000069_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000074_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000075_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000076_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000077_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000078_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000079_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000080_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000081_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000087_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000088_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000089_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000090_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000091_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000092_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000093_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000100_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000101_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000102_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000103_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000104_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000105_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31300/000116_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000026_27-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000027_28-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000028_29-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000029_30-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000039_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000040_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000056_24-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000057_25-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000058_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000059_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000060_28-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000061_29-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000062_30-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000063_31-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000067_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000068_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000069_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000070_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000071_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000072_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000073_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000074_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000075_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000088_23-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000089_24-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000090_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000091_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000092_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000093_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000094_29-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000095_30-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000096_31-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000097_32-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000099_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000100_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000101_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000102_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000103_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000104_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000105_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000106_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000107_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000108_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000121_23-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000122_24-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000123_25-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000124_26-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000125_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000126_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000127_29-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000128_30-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000129_31-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000130_32-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000131_33-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000132_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000133_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000134_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000135_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000136_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000137_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000138_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000139_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000140_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000141_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000142_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000154_23-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000155_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000156_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000157_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000158_27-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000159_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000160_29-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000161_30-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000162_31-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000163_32-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000165_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000166_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000167_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000168_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000169_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000170_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000171_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000172_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000173_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000174_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000188_24-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000189_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000190_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000191_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000192_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000193_29-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000194_30-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000195_31-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000196_32-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000200_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000201_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000202_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000203_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000204_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000205_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000206_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000207_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000222_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000223_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000224_27-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000225_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000226_29-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000227_30-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000228_31-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000229_32-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000233_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000234_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000235_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000236_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000237_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000238_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000239_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000240_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000255_25-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000256_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000257_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000258_28-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000259_29-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000260_30-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000261_31-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000262_32-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000266_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000267_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000268_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000269_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000270_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000271_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000272_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000273_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000288_25-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000289_26-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000290_27-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000291_28-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000292_29-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000293_30-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000294_31-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000299_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000300_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000301_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000302_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000303_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000304_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000305_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000321_25-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000322_26-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000323_27-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000324_28-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000325_29-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000326_30-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000332_3-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000333_4-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000334_5-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000335_6-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000336_7-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/31333/000337_8-11.png
# ...
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000018_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000019_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000020_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000021_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000022_9-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000023_10-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000024_11-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000025_12-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000029_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000030_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000031_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000032_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000033_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000034_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000035_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000036_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000037_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000038_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000039_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000040_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000041_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000042_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000043_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000044_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000045_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000046_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000047_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000048_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000049_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000050_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000051_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000052_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000053_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000054_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000055_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000056_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000057_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000058_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000059_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000060_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000061_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000062_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000063_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000064_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000065_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000066_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000067_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000068_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000070_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000071_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000072_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000073_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000074_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000075_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000076_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000077_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000078_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000079_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000080_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000081_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000082_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000085_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000086_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000087_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000088_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000089_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000090_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000091_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000092_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000093_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000094_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000095_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000100_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000101_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000102_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000103_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000104_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000105_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000106_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000107_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000108_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000114_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000115_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000116_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000117_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000118_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000119_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000120_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000121_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000129_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000130_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000134_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34688/000135_10-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000001_2-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000022_1-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000023_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000024_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000025_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000044_1-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000045_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000046_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000047_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000048_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000049_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000050_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000053_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000054_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000055_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000056_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000057_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000058_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000066_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000067_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000068_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000069_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000070_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000071_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000072_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000073_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000074_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000075_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000076_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000077_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000078_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000079_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000080_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000081_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000082_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000083_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000084_19-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000085_20-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000086_21-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000087_22-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000088_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000089_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000090_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000091_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000092_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000093_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000094_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000095_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000096_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000097_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000098_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000099_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000100_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000101_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000102_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000103_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000104_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000105_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000106_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000107_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000108_21-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000109_22-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000110_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000111_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000112_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000113_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000114_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000115_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000116_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000117_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000118_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000119_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000120_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000121_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000122_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000123_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000124_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000125_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000126_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000127_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000128_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000129_20-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000130_21-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000131_22-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000132_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000133_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000134_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000135_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000136_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000137_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000138_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000139_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000140_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000141_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000142_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000143_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/34690/000144_13-7.png

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %%
# df = pd.read_csv('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/train.csv')
# df[df.image_id==int(folders[1].split('/')[-1])].is_tma.values
# from glob import glob
# folders = glob('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/*')
# for f in sorted(folders, key=lambda x: int(x.split('/')[-1]) if x.split('/')[-1]!='train.csv' else 999999)[:-1]:
#     tma=False
#     if df[df.image_id==int(f.split('/')[-1])].is_tma.values[0]:
#         tma=True
#     print(f.split('/')[-1], len(glob(f+'/*png')), tma)

# %% [markdown]
# # Config

# %%
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
tile_size = 512
image_size = 512
n_tiles = 4 if DEBUG else 9
batch_size = 4
num_workers = os.cpu_count()
out_dim = 5
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 20
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    # if 4 <= image_id <= 15188:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-1')
    # elif 15209 <= image_id <= 30515:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-2')
    # elif 30539 <= image_id <= 38687:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-3')
    # elif 38849 <= image_id <= 65300:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-4')
    # elif 65371 <= image_id <= 65533:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-5')
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください

class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features, out_dim)
        self.enet.classifier = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
        x = self.myfc(x)
        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
import joblib
good_images = joblib.load(os.path.join(OUTPUT, 'bw_checker/good_images.pkl'))

# %%
def get_tiles(paths):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)

        # Pillow ImageオブジェクトをNumPy配列に変換
        image_array = np.array(image)
        ret.append(image_array)
    return ret


class PANDADataset(Dataset):
    def __init__(self,
                 df,
                 image_size,
                 n_tiles=n_tiles,
                 tile_mode=0,
                 rand=False,
                 transform=None,
                ):

        self.df = df.reset_index(drop=True)
        self.image_size = image_size
        self.n_tiles = n_tiles
        self.tile_mode = tile_mode
        self.rand = rand
        self.transform = transform

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]
        img_id = row.image_id


        try:
            tiles = good_images[img_id]
        except:
            files = os.listdir(row.tile_path)
            tiles = [row.tile_path + f'/{e}' for e in files]
        if DEBUG:
            tiles = [t.replace('/content/tmp', INPUT) for t in tiles]
        n_imgs = len(tiles)
        tiles = get_tiles(tiles)


        if self.rand:
            idxes = np.random.choice(list(range(self.n_tiles)), self.n_tiles, replace=False)
        else:
            idxes = list(range(self.n_tiles))

        n_row_tiles = int(np.sqrt(self.n_tiles))
        images = np.zeros((image_size * n_row_tiles, image_size * n_row_tiles, 3))
        for h in range(n_row_tiles):
            for w in range(n_row_tiles):
                i = h * n_row_tiles + w

                # fill all tiles(exp014)
                try:
                    this_img = tiles[idxes[i%n_imgs]]
                except:
                    this_img = np.ones((self.image_size, self.image_size, 3)).astype(np.uint8) * 255
                # if len(tiles) > idxes[i]:
                #     this_img = tiles[idxes[i]]
                # else:
                #
                this_img = 255 - this_img
                if self.transform is not None:
                    this_img = self.transform(image=this_img)['image']
                h1 = h * image_size
                w1 = w * image_size
                images[h1:h1+image_size, w1:w1+image_size] = this_img

        # if self.transform is not None:
        #     images = self.transform(image=images)['image']
        images = images.astype(np.float32)
        # images /= 255
        images = images.transpose(2, 0, 1)

        # default label
        label = np.zeros(out_dim).astype(np.float32)
        label[l2n[row.label]] = 1.

        #label smoothing(exp006)
        # eps = 0.05
        # label = np.ones(out_dim).astype(np.float32) * eps/out_dim
        # label[l2n[row.label]] += (1. - eps)

        return torch.tensor(images), torch.tensor(label)

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
# dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, transform=transforms_train)
# from pylab import rcParams
# rcParams['figure.figsize'] = 20,10
# for i in range(2):
#     f, axarr = plt.subplots(1,5)
#     for p in range(5):
#         idx = np.random.randint(0, len(dataset_show))
#         img, label = dataset_show[idx]
#         axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
#         axarr[p].set_title(label)

# %% [markdown]
# # Loss

# %%
# labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
# pos_weight = torch.tensor([1.0, 3.0, 3.0, 3.0, 1.0], dtype=torch.float32)
# pos_weight = pos_weight.to(device)
# criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

criterion = nn.BCEWithLogitsLoss()
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
# def train_epoch(loader, optimizer):

#     model.train()
#     train_loss = []
#     bar = tqdm(loader)
#     for (data, target) in bar:

#         data, target = data.to(device), target.to(device)
#         loss_func = criterion
#         optimizer.zero_grad()
#         logits = model(data)
#         loss = loss_func(logits, target)
#         loss.backward()
#         optimizer.step()

#         loss_np = loss.detach().cpu().numpy()
#         train_loss.append(loss_np)
#         smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
#         bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
#     return train_loss


# prompt: def train_epoch(loader, optimizer):      model.train()     train_loss = []     bar = tqdm(loader)     for (data, target) in bar:          data, target = data.to(device), target.to(device)         loss_func = criterion         optimizer.zero_grad()         logits = model(data)         loss = loss_func(logits, target)         loss.backward()         optimizer.step()          loss_np = loss.detach().cpu().numpy()         train_loss.append(loss_np)         smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)         bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))     return train_lossをtorch.autocast and torch.cuda.amp.GradScalerをつかって書き換えて

def train_epoch(loader, optimizer):
    model.train()
    train_loss = []
    bar = tqdm(loader)
    scaler = torch.cuda.amp.GradScaler()
    for (data, target) in bar:
        data, target = data.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            logits = model(data)
            loss = loss_func(logits, target)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, target) in tqdm(loader):
            data, target = data.to(device), target.to(device)
            logits = model(data)

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
#     acc = (PREDS == TARGETS).mean() * 100.
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

#     qwk = cohen_kappa_score(PREDS, TARGETS, weights='quadratic')
#     qwk_k = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'karolinska'], df_valid[df_valid['data_provider'] == 'karolinska'].isup_grade.values, weights='quadratic')
#     qwk_r = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'radboud'], df_valid[df_valid['data_provider'] == 'radboud'].isup_grade.values, weights='quadratic')
#     print('qwk', qwk, 'qwk_k', qwk_k, 'qwk_r', qwk_r)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo, eta_min=1.0e-4)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))

# %% [markdown]
# # Run Training

# %%
def mymetric(df):
    cols = df['label'].unique().tolist()
    recalls = dict()
    for col in cols:
        df_ = df.query('label==@col')
        recalls[col] = (df_['label']==df_['pred']).sum()/df_.shape[0]
    score = 0
    for k, v in recalls.items():
        score += v
    score /= len(cols)
    return score, recalls

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)
    df_valid['pred'] = oof_preds.argmax(1)
    df_valid['pred'] = df_valid['pred'].map(n2l)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}, '
    content += str(mymetric(df_valid))
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
# Out:
# Thu Dec 14 15:41:40 2023 Epoch: 1
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.39555555555555555
# Thu Dec 14 15:58:33 2023 Epoch 1, lr: 0.0000300, train loss: 0.57576, val loss: 0.48425, balanced accuracy: 0.39556, (0.39555555555555555, {'HGSC': 0.8666666666666667, 'CC': 0.6, 'EC': 0.4, 'MC': 0.1111111111111111, 'LGSC': 0.0})
# score2 (0.000000 --> 0.395556).  Saving model ...
# Thu Dec 14 15:58:34 2023 Epoch: 2
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.5917777777777777
# Thu Dec 14 16:15:21 2023 Epoch 2, lr: 0.0003000, train loss: 0.37223, val loss: 0.32153, balanced accuracy: 0.59178, (0.5917777777777777, {'HGSC': 0.6222222222222222, 'CC': 0.95, 'EC': 0.72, 'MC': 0.4444444444444444, 'LGSC': 0.2222222222222222})
# score2 (0.395556 --> 0.591778).  Saving model ...
# Thu Dec 14 16:15:21 2023 Epoch: 3
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.684
# Thu Dec 14 16:32:12 2023 Epoch 3, lr: 0.0000300, train loss: 0.29296, val loss: 0.27295, balanced accuracy: 0.68400, (0.684, {'HGSC': 0.6888888888888889, 'CC': 0.9, 'EC': 0.72, 'MC': 0.7777777777777778, 'LGSC': 0.3333333333333333})
# score2 (0.591778 --> 0.684000).  Saving model ...
# Thu Dec 14 16:32:12 2023 Epoch: 4
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6991111111111111
# Thu Dec 14 16:48:53 2023 Epoch 4, lr: 0.0002946, train loss: 0.30622, val loss: 0.29536, balanced accuracy: 0.69911, (0.6991111111111111, {'HGSC': 0.7111111111111111, 'CC': 0.9, 'EC': 0.44, 'MC': 1.0, 'LGSC': 0.4444444444444444})
# score2 (0.684000 --> 0.699111).  Saving model ...
# Thu Dec 14 16:48:53 2023 Epoch: 5
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6742222222222223
# Thu Dec 14 17:05:28 2023 Epoch 5, lr: 0.0002879, train loss: 0.27397, val loss: 0.32724, balanced accuracy: 0.67422, (0.6742222222222222, {'HGSC': 0.6, 'CC': 0.9, 'EC': 0.76, 'MC': 0.7777777777777778, 'LGSC': 0.3333333333333333})
# Thu Dec 14 17:05:28 2023 Epoch: 6
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7084444444444444
# Thu Dec 14 17:22:06 2023 Epoch 6, lr: 0.0002789, train loss: 0.27054, val loss: 0.29769, balanced accuracy: 0.70844, (0.7084444444444443, {'HGSC': 0.6888888888888889, 'CC': 0.8, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.4444444444444444})
# score2 (0.699111 --> 0.708444).  Saving model ...
# Thu Dec 14 17:22:06 2023 Epoch: 7
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7313333333333334
# Thu Dec 14 17:38:58 2023 Epoch 7, lr: 0.0002677, train loss: 0.23109, val loss: 0.33296, balanced accuracy: 0.73133, (0.7313333333333334, {'HGSC': 0.6, 'CC': 0.75, 'EC': 0.64, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# score2 (0.708444 --> 0.731333).  Saving model ...
# Thu Dec 14 17:38:59 2023 Epoch: 8
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6877777777777777
# Thu Dec 14 17:55:47 2023 Epoch 8, lr: 0.0002547, train loss: 0.23176, val loss: 0.28717, balanced accuracy: 0.68778, (0.6877777777777778, {'HGSC': 0.6666666666666666, 'CC': 0.95, 'EC': 0.6, 'MC': 0.8888888888888888, 'LGSC': 0.3333333333333333})
# Thu Dec 14 17:55:47 2023 Epoch: 9
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6906666666666667
# Thu Dec 14 18:12:33 2023 Epoch 9, lr: 0.0002402, train loss: 0.21180, val loss: 0.28864, balanced accuracy: 0.69067, (0.6906666666666667, {'HGSC': 0.7111111111111111, 'CC': 0.8, 'EC': 0.72, 'MC': 0.7777777777777778, 'LGSC': 0.4444444444444444})
# Thu Dec 14 18:12:33 2023 Epoch: 10
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7191111111111111
# Thu Dec 14 18:29:22 2023 Epoch 10, lr: 0.0002245, train loss: 0.17679, val loss: 0.26336, balanced accuracy: 0.71911, (0.7191111111111111, {'HGSC': 0.6222222222222222, 'CC': 0.8, 'EC': 0.84, 'MC': 1.0, 'LGSC': 0.3333333333333333})
# Thu Dec 14 18:29:22 2023 Epoch: 11
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7315555555555555
# Thu Dec 14 18:46:25 2023 Epoch 11, lr: 0.0002083, train loss: 0.16878, val loss: 0.23977, balanced accuracy: 0.73156, (0.7315555555555555, {'HGSC': 0.7333333333333333, 'CC': 0.8, 'EC': 0.68, 'MC': 1.0, 'LGSC': 0.4444444444444444})
# score2 (0.731333 --> 0.731556).  Saving model ...
# Thu Dec 14 18:46:25 2023 Epoch: 12
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7348888888888888
# Thu Dec 14 19:03:30 2023 Epoch 12, lr: 0.0001917, train loss: 0.16144, val loss: 0.30843, balanced accuracy: 0.73489, (0.7348888888888888, {'HGSC': 0.6888888888888889, 'CC': 0.75, 'EC': 0.68, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# score2 (0.731556 --> 0.734889).  Saving model ...
# Thu Dec 14 19:03:30 2023 Epoch: 13
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7495555555555555
# Thu Dec 14 19:20:31 2023 Epoch 13, lr: 0.0001755, train loss: 0.14575, val loss: 0.24720, balanced accuracy: 0.74956, (0.7495555555555555, {'HGSC': 0.7333333333333333, 'CC': 0.85, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# score2 (0.734889 --> 0.749556).  Saving model ...
# Thu Dec 14 19:20:31 2023 Epoch: 14
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7295555555555555
# Thu Dec 14 19:37:20 2023 Epoch 14, lr: 0.0001598, train loss: 0.12347, val loss: 0.32418, balanced accuracy: 0.72956, (0.7295555555555555, {'HGSC': 0.6222222222222222, 'CC': 0.75, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Thu Dec 14 19:37:20 2023 Epoch: 15
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7157777777777778
# Thu Dec 14 19:54:27 2023 Epoch 15, lr: 0.0001453, train loss: 0.12306, val loss: 0.27393, balanced accuracy: 0.71578, (0.7157777777777777, {'HGSC': 0.6444444444444445, 'CC': 0.85, 'EC': 0.64, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# Thu Dec 14 19:54:27 2023 Epoch: 16
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7442222222222221
# Thu Dec 14 20:11:51 2023 Epoch 16, lr: 0.0001323, train loss: 0.09922, val loss: 0.27661, balanced accuracy: 0.74422, (0.7442222222222222, {'HGSC': 0.6666666666666666, 'CC': 0.85, 'EC': 0.76, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# Thu Dec 14 20:11:51 2023 Epoch: 17
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7637777777777777
# Thu Dec 14 20:29:08 2023 Epoch 17, lr: 0.0001211, train loss: 0.10374, val loss: 0.27142, balanced accuracy: 0.76378, (0.7637777777777777, {'HGSC': 0.7333333333333333, 'CC': 0.85, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# score2 (0.749556 --> 0.763778).  Saving model ...
# Thu Dec 14 20:29:09 2023 Epoch: 18
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7335555555555555
# Thu Dec 14 20:46:19 2023 Epoch 18, lr: 0.0001121, train loss: 0.10036, val loss: 0.25866, balanced accuracy: 0.73356, (0.7335555555555555, {'HGSC': 0.8222222222222222, 'CC': 0.85, 'EC': 0.44, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Thu Dec 14 20:46:19 2023 Epoch: 19
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7362222222222221
# Thu Dec 14 21:03:36 2023 Epoch 19, lr: 0.0001054, train loss: 0.08097, val loss: 0.30691, balanced accuracy: 0.73622, (0.7362222222222222, {'HGSC': 0.6666666666666666, 'CC': 0.85, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# Thu Dec 14 21:03:36 2023 Epoch: 20
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7393333333333334
# Thu Dec 14 21:20:56 2023 Epoch 20, lr: 0.0001014, train loss: 0.07469, val loss: 0.28434, balanced accuracy: 0.73933, (0.7393333333333333, {'HGSC': 0.7333333333333333, 'CC': 0.95, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.4444444444444444})
# comp metric max 0.7637777777777777
# CPU times: user 16min 23s, sys: 3min 17s, total: 19min 40s
# Wall time: 5h 39min 15s
