# %%
# !nvidia-smi
# Out:
# Wed Dec 13 06:02:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "exp050" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

DEBUG = False

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Using cached kaggle-1.5.16-py3-none-any.whl
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)
    # EXP_MODEL = os.path.join(OUTPUT_EXP, "model")
    # EXP_FIG = os.path.join(OUTPUT_EXP, "fig")
    # EXP_PREDS = os.path.join(OUTPUT_EXP, "preds")

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab

# %%
# %%time
if not DEBUG:
    # tmp fileに直接ダウンロードする
    TMP = '/content/tmp'
    INPUT = '/content/tmp'
    # !mkdir $TMP
    files = [
        'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
            #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
            #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
            #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
        'jirkaborovec/tiles-of-cancer-2048px-scale-0-25',
        'tyabanoamami/ucbo-thumbnail-data',
            ]
    for f in files:
        # !kaggle datasets download -d $f -p $TMP
        t = f.split('/')[1]
        unzip_file = os.path.join(TMP, f'{t}.zip')
        unzip_file_ = TMP + '/' + t
        INPUT_ = INPUT + '/' + t
        ! unzip $unzip_file -d $unzip_file_
        # !mv $unzip_file_ $INPUT_
        # !rm -rf $unzip_file
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000082_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000083_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000084_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000087_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000088_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000089_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000090_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000091_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000092_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000093_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000094_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000095_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000096_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000097_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000098_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000099_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000100_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000101_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000102_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000103_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000104_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000105_19-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000106_20-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000107_21-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000108_22-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000109_23-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000110_24-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000111_25-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000112_26-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000113_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000114_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000116_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000117_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000118_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000119_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000120_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000121_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000122_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000123_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000124_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000125_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000126_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000127_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000128_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000129_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000130_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000131_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000132_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000133_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000134_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000135_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000136_21-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000137_22-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000138_23-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000139_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000140_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000141_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000142_27-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000143_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000145_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000146_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000147_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000148_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000149_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000150_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000151_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000152_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000153_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000154_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000155_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000156_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000157_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000158_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000159_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000160_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000161_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000162_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000163_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000164_20-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000165_21-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000166_22-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000167_23-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000168_24-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000169_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000170_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000171_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000172_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000174_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000175_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000176_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000177_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000178_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000179_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000180_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000181_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000182_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000183_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000184_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000185_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000186_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000187_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000188_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000189_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000190_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000191_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000192_19-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000193_20-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000194_21-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000195_22-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000196_23-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000197_24-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000198_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000199_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000200_27-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000201_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000204_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000205_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000206_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000207_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000208_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000209_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000210_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000211_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000212_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000213_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000214_12-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000215_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000216_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000217_15-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000218_16-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000219_17-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000220_18-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000221_19-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000222_20-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000223_21-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000224_22-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000225_23-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000226_24-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000227_25-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000228_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000229_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000230_28-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000231_29-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000233_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000234_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000235_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000236_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000237_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000238_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000239_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000240_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000241_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000242_11-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000243_12-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000244_13-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000245_14-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000246_15-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000247_16-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000248_17-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000249_18-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000250_19-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000251_20-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000252_21-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000253_22-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000254_23-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000255_24-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000256_25-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000257_26-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000258_27-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000259_28-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000260_29-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000261_1-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000262_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000263_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000264_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000265_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000266_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000267_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000268_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000269_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000270_10-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000271_11-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000272_12-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000273_13-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000274_14-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000275_15-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000276_16-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000277_17-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000278_18-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000279_19-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000280_20-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000281_21-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000282_22-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000283_23-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000284_24-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000285_25-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000286_26-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000287_27-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000288_28-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000289_29-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000290_1-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000291_2-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000292_3-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000293_4-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000294_5-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000295_6-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000296_7-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000297_8-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000298_9-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000299_10-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000300_11-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000301_12-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000302_13-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000303_14-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000304_15-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000305_16-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000306_17-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000307_18-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000308_19-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000309_20-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000310_21-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000311_22-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000312_23-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000313_24-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000314_25-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000315_26-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000316_27-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000317_28-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000318_29-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000319_1-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000320_2-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000321_3-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000322_4-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000323_5-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000324_6-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000325_7-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000326_8-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000327_9-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000328_10-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000329_11-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000330_12-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000331_13-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000332_14-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000333_15-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000334_16-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000335_17-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000336_18-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000337_19-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000338_20-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000339_21-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000340_22-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000341_23-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000342_24-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000343_25-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000344_26-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000345_27-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000346_28-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000347_29-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000349_2-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000350_3-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000351_4-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000352_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000353_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000354_7-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000355_8-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000356_9-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000357_10-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000358_11-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000359_12-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000360_13-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000361_14-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000362_15-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000363_16-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000364_17-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000365_18-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000366_19-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000367_20-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000368_21-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000369_22-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000370_23-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000371_24-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000372_25-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000373_26-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000374_27-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000375_28-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000376_29-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000380_4-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000381_5-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000382_6-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000383_7-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000384_8-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000385_9-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000386_10-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000387_11-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000388_12-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000389_13-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000390_14-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000391_15-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000392_16-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000393_17-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000394_18-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000395_19-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000396_20-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000397_21-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000398_22-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000399_23-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000400_24-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000401_25-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000402_26-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000403_27-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000404_28-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000405_29-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000417_12-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000418_13-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000419_14-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000420_15-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000421_16-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000422_17-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000423_18-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000424_19-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000425_20-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000426_21-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000427_22-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000428_23-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000429_24-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000430_25-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000431_26-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000432_27-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000433_28-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000434_29-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000457_23-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000458_24-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000459_25-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000460_26-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000461_27-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000462_28-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7490/000463_29-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000000_1-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000001_2-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000013_14-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000014_15-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000026_27-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000032_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000033_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000034_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000035_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000044_14-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000045_15-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000046_16-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000047_17-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000056_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000057_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000058_28-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000059_29-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000063_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000064_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000065_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000066_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000067_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000075_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000076_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000077_16-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000078_17-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000079_18-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000087_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000088_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000089_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000090_29-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000091_30-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000095_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000096_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000097_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000098_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000099_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000106_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000107_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000108_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000109_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000110_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000119_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000120_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000121_29-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000122_30-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000123_31-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000124_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000125_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000126_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000127_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000128_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000129_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000130_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000139_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000140_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000141_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000142_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000151_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000152_29-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000153_30-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000154_31-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000155_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000156_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000157_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000158_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000159_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000160_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000167_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000168_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000169_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000170_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000171_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000172_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000173_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000180_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000181_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000182_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000183_29-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000184_30-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000185_31-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000186_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000187_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000188_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000189_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000198_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000199_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000200_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000201_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000202_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000203_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000210_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000211_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000212_27-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000213_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000214_29-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000215_30-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000229_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000230_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000231_15-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000232_16-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000242_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000243_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/7955/000244_28-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000004_5-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000005_6-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000025_26-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000034_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000035_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000036_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000037_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000038_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000039_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000056_24-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000057_25-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000058_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000059_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000067_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000068_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000069_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000070_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000071_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000072_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000073_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000074_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000087_22-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000088_23-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000089_24-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000090_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000091_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000092_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000093_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000094_29-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000099_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000100_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000101_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000102_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000103_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000104_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000105_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000106_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000107_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000108_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000120_22-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000121_23-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000122_24-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000123_25-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000124_26-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000125_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000126_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000127_29-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000132_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000133_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000134_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000135_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000136_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000137_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000138_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000139_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000140_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000141_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000142_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000152_21-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000153_22-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000154_23-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000155_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000156_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000157_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000158_27-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000159_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000160_29-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000161_30-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000165_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000166_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000167_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000168_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000169_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000170_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000171_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000172_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000173_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000174_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000175_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000185_21-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000186_22-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000187_23-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000188_24-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000189_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000190_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000191_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000192_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000193_29-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000194_30-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000195_31-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000199_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000200_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000201_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000202_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000203_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000204_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000205_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000206_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000207_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000208_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000218_21-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000219_22-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000220_23-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000221_24-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000222_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000223_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000224_27-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000225_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000226_29-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000227_30-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000228_31-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000232_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000233_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000234_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000235_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000236_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000237_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000238_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000239_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000240_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000241_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000252_22-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000253_23-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000254_24-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000255_25-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000256_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000257_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000258_28-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000259_29-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000260_30-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000261_31-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000265_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000266_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/8130/000267_4-9.png
# ...
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/43815.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/43875.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/43998.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44232.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44283.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44432.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44530.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44581.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44603.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44700.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44804.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44962.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/44976.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45104.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45185.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45254.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45578.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45630.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45725.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/45990.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/4608.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46139.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46172.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46435.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46444.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46469.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46543.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46688.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46736.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46769.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46793.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/46815.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47020.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47035.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47105.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47431.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47837.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47911.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47960.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/4797.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/47984.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/4827.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48502.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48506.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48550.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48734.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/4877.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48861.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/48973.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/49281.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/49587.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/4963.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/49872.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/49942.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/49995.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50048.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5015.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50246.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50304.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50589.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50712.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50878.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50932.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/50962.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51021.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51032.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51128.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5114.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51215.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51346.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51499.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51679.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51832.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/51893.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52108.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52259.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52275.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52308.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52375.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52420.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52438.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52461.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5251.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52612.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5264.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5265.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52752.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52784.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52836.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52846.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/52931.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53059.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5307.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53098.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53377.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53402.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53655.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53688.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53859.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/53900.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54007.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54408.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54473.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54506.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5456.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54590.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54825.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54928.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54949.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/54990.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/55279.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/55281.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/55287.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/55876.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56117.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56221.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56351.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56500.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56799.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56843.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56861.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56875.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56947.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/56993.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57100.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57162.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57265.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57468.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57598.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57696.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/57711.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5851.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5852.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/58895.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/58947.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/58974.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59002.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59031.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59383.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59515.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59589.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5970.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59760.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/59900.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/5992.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60058.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60287.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60685.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60928.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60936.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/60988.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61033.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61089.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61100.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61280.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61320.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6140.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61424.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61493.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61689.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6175.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61797.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61823.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61852.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/61961.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/62476.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/62641.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6281.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/62828.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63015.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63121.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63165.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63289.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63298.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63367.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63429.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6359.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6363.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63836.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63897.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/63941.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64111.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64188.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6449.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64629.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64771.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64824.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/64950.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/65022.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/65094.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/65300.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/65371.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/65533.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6558.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6582.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/66.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6793.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6843.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6898.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/6951.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/706.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/7204.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/7329.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/7482.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/7490.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/7955.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8130.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8213.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8240.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8279.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8280.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8531.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8713.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8805.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/8985.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/91.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9154.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9183.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9200.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9254.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9341.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9509.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9658.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/9697.png
#   inflating: /content/tmp/ucbo-thumbnail-data/train_images/970.png
# CPU times: user 15.1 s, sys: 2.15 s, total: 17.2 s
# Wall time: 20min 22s

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm
# Out:
# Collecting git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
#   Cloning https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to /tmp/pip-req-build-lh1lqsca
#   Running command git clone --filter=blob:none --quiet https://github.com/ildoonet/pytorch-gradual-warmup-lr.git /tmp/pip-req-build-lh1lqsca
#   Resolved https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to commit 6b5e8953a80aef5b324104dc0c2e9b8c34d622bd
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (0.9.12)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %%
# df = pd.read_csv('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/train.csv')
# df[df.image_id==int(folders[1].split('/')[-1])].is_tma.values
# from glob import glob
# folders = glob('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/*')
# for f in sorted(folders, key=lambda x: int(x.split('/')[-1]) if x.split('/')[-1]!='train.csv' else 999999)[:-1]:
#     tma=False
#     if df[df.image_id==int(f.split('/')[-1])].is_tma.values[0]:
#         tma=True
#     print(f.split('/')[-1], len(glob(f+'/*png')), tma)

# %% [markdown]
# # Config

# %%
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
tile_size = 512
image_size = 512
n_tiles = 4 if DEBUG else 9
batch_size = 4
num_workers = os.cpu_count()
out_dim = 5
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 30
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()
# Out:
# /content/tmp/tiles-of-cancer-2048px-scale-0-25/train_images

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    # if 4 <= image_id <= 15188:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-1')
    # elif 15209 <= image_id <= 30515:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-2')
    # elif 30539 <= image_id <= 38687:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-3')
    # elif 38849 <= image_id <= 65300:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-4')
    # elif 65371 <= image_id <= 65533:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-5')
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください

class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.enet2 = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features * 2, out_dim)
        self.enet.classifier = nn.Identity()
        self.enet2.classifier = nn.Identity()

    def extract(self, x):
        x = torch.concat([self.enet(x[0]), self.enet2(x[1])], 1)
        return x

    def forward(self, x):
        x = self.extract(x)
        x = self.myfc(x)
        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
import joblib
good_images = joblib.load(os.path.join(OUTPUT, 'bw_checker/good_images.pkl'))

# %%
def get_tiles(paths):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)

        # Pillow ImageオブジェクトをNumPy配列に変換
        image_array = np.array(image)
        ret.append(image_array)
    return ret


class PANDADataset(Dataset):
    def __init__(self,
                 df,
                 image_size,
                 n_tiles=n_tiles,
                 tile_mode=0,
                 rand=False,
                 transform=None,
                ):

        self.df = df.reset_index(drop=True)
        self.image_size = image_size
        self.n_tiles = n_tiles
        self.tile_mode = tile_mode
        self.rand = rand
        self.transform = transform

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]
        img_id = row.image_id


        try:
            tiles = good_images[img_id]
        except:
            files = os.listdir(row.tile_path)
            tiles = [row.tile_path + f'/{e}' for e in files]
        if DEBUG:
            tiles = [t.replace('/content/tmp', INPUT) for t in tiles]
        n_imgs = len(tiles)
        tiles = get_tiles(tiles)


        if self.rand:
            idxes = np.random.choice(list(range(self.n_tiles)), self.n_tiles, replace=False)
        else:
            idxes = list(range(self.n_tiles))

        n_row_tiles = int(np.sqrt(self.n_tiles))
        images = np.zeros((image_size * n_row_tiles, image_size * n_row_tiles, 3))
        for h in range(n_row_tiles):
            for w in range(n_row_tiles):
                i = h * n_row_tiles + w

                # fill all tiles(exp014)
                try:
                    this_img = tiles[idxes[i%n_imgs]]
                except:
                    this_img = np.ones((self.image_size, self.image_size, 3)).astype(np.uint8) * 255
                # if len(tiles) > idxes[i]:
                #     this_img = tiles[idxes[i]]
                # else:
                #
                this_img = 255 - this_img
                if self.transform is not None:
                    this_img = self.transform(image=this_img)['image']
                h1 = h * image_size
                w1 = w * image_size
                images[h1:h1+image_size, w1:w1+image_size] = this_img


        images = images.astype(np.float32)
        images = images.transpose(2, 0, 1)

        # default label
        label = np.zeros(out_dim).astype(np.float32)
        label[l2n[row.label]] = 1.

        #label smoothing(exp006)
        # eps = 0.05
        # label = np.ones(out_dim).astype(np.float32) * eps/out_dim
        # label[l2n[row.label]] += (1. - eps)

        ### thumbnail images
        path = os.path.join(INPUT, f'ucbo-thumbnail-data/train_images/{img_id}.png')
        image2 = PIL.Image.open(path)
        image2 = np.array(image2)
        image2 = 255 - image2
        if self.transform is not None:
            image2 = self.transform(image=image2)['image']
        image2 = image2.astype(np.float32)
        image2 = image2.transpose(2, 0, 1)


        return torch.tensor(images), torch.tensor(image2) , torch.tensor(label)

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
# dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, transform=transforms_train)
# from pylab import rcParams
# rcParams['figure.figsize'] = 20,10
# for i in range(2):
#     f, axarr = plt.subplots(1,5)
#     for p in range(5):
#         idx = np.random.randint(0, len(dataset_show))
#         img, label = dataset_show[idx]
#         axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
#         axarr[p].set_title(label)

# %% [markdown]
# # Loss

# %%
# labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
# pos_weight = torch.tensor([1.0, 3.0, 3.0, 3.0, 1.0], dtype=torch.float32)
# pos_weight = pos_weight.to(device)
# criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

criterion = nn.BCEWithLogitsLoss()
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
# def train_epoch(loader, optimizer):

#     model.train()
#     train_loss = []
#     bar = tqdm(loader)
#     for (data, target) in bar:

#         data, target = data.to(device), target.to(device)
#         loss_func = criterion
#         optimizer.zero_grad()
#         logits = model(data)
#         loss = loss_func(logits, target)
#         loss.backward()
#         optimizer.step()

#         loss_np = loss.detach().cpu().numpy()
#         train_loss.append(loss_np)
#         smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
#         bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
#     return train_loss


# prompt: def train_epoch(loader, optimizer):      model.train()     train_loss = []     bar = tqdm(loader)     for (data, target) in bar:          data, target = data.to(device), target.to(device)         loss_func = criterion         optimizer.zero_grad()         logits = model(data)         loss = loss_func(logits, target)         loss.backward()         optimizer.step()          loss_np = loss.detach().cpu().numpy()         train_loss.append(loss_np)         smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)         bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))     return train_lossをtorch.autocast and torch.cuda.amp.GradScalerをつかって書き換えて

def train_epoch(loader, optimizer):
    model.train()
    train_loss = []
    bar = tqdm(loader)
    scaler = torch.cuda.amp.GradScaler()
    for (data, data2, target) in bar:
        data, data2, target = data.to(device), data2.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            logits = model((data, data2))
            loss = loss_func(logits, target)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, data2, target) in tqdm(loader):
            data, data2, target = data.to(device), data2.to(device), target.to(device)
            logits = model((data, data2))

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))
# Out:
# 430 108

# %% [markdown]
# # Run Training

# %%
def mymetric(df):
    cols = df['label'].unique().tolist()
    recalls = dict()
    for col in cols:
        df_ = df.query('label==@col')
        recalls[col] = (df_['label']==df_['pred']).sum()/df_.shape[0]
    score = 0
    for k, v in recalls.items():
        score += v
    score /= len(cols)
    return score, recalls

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)
    df_valid['pred'] = oof_preds.argmax(1)
    df_valid['pred'] = df_valid['pred'].map(n2l)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}, '
    content += str(mymetric(df_valid))
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
# Out:
# Wed Dec 13 06:22:11 2023 Epoch: 1
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.3257777777777778
# Wed Dec 13 06:41:44 2023 Epoch 1, lr: 0.0000300, train loss: 0.54420, val loss: 0.45638, balanced accuracy: 0.32578, (0.3257777777777778, {'HGSC': 0.8888888888888888, 'CC': 0.5, 'EC': 0.24, 'MC': 0.0, 'LGSC': 0.0})
# score2 (0.000000 --> 0.325778).  Saving model ...
# Wed Dec 13 06:41:44 2023 Epoch: 2
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.5448888888888889
# Wed Dec 13 07:01:00 2023 Epoch 2, lr: 0.0003000, train loss: 0.39011, val loss: 0.31418, balanced accuracy: 0.54489, (0.5448888888888889, {'HGSC': 0.7777777777777778, 'CC': 0.8, 'EC': 0.48, 'MC': 0.6666666666666666, 'LGSC': 0.0})
# score2 (0.325778 --> 0.544889).  Saving model ...
# Wed Dec 13 07:01:01 2023 Epoch: 3
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6713333333333333
# Wed Dec 13 07:20:18 2023 Epoch 3, lr: 0.0000300, train loss: 0.30740, val loss: 0.27673, balanced accuracy: 0.67133, (0.6713333333333333, {'HGSC': 0.7555555555555555, 'CC': 0.85, 'EC': 0.64, 'MC': 0.8888888888888888, 'LGSC': 0.2222222222222222})
# score2 (0.544889 --> 0.671333).  Saving model ...
# Wed Dec 13 07:20:19 2023 Epoch: 4
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6253333333333334
# Wed Dec 13 07:39:42 2023 Epoch 4, lr: 0.0002965, train loss: 0.32110, val loss: 0.36607, balanced accuracy: 0.62533, (0.6253333333333334, {'HGSC': 0.6444444444444445, 'CC': 0.9, 'EC': 0.36, 'MC': 0.8888888888888888, 'LGSC': 0.3333333333333333})
# Wed Dec 13 07:39:42 2023 Epoch: 5
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6811111111111111
# Wed Dec 13 07:58:55 2023 Epoch 5, lr: 0.0002921, train loss: 0.28055, val loss: 0.29353, balanced accuracy: 0.68111, (0.6811111111111111, {'HGSC': 0.6444444444444445, 'CC': 0.85, 'EC': 0.8, 'MC': 0.7777777777777778, 'LGSC': 0.3333333333333333})
# score2 (0.671333 --> 0.681111).  Saving model ...
# Wed Dec 13 07:58:55 2023 Epoch: 6
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6542222222222221
# Wed Dec 13 08:17:57 2023 Epoch 6, lr: 0.0002861, train loss: 0.26394, val loss: 0.25809, balanced accuracy: 0.65422, (0.6542222222222221, {'HGSC': 0.7333333333333333, 'CC': 1.0, 'EC': 0.76, 'MC': 0.5555555555555556, 'LGSC': 0.2222222222222222})
# Wed Dec 13 08:17:57 2023 Epoch: 7
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.8104444444444443
# Wed Dec 13 08:37:19 2023 Epoch 7, lr: 0.0002785, train loss: 0.21886, val loss: 0.23231, balanced accuracy: 0.81044, (0.8104444444444445, {'HGSC': 0.8666666666666667, 'CC': 0.95, 'EC': 0.68, 'MC': 0.8888888888888888, 'LGSC': 0.6666666666666666})
# score2 (0.681111 --> 0.810444).  Saving model ...
# Wed Dec 13 08:37:19 2023 Epoch: 8
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7113333333333334
# Wed Dec 13 08:56:37 2023 Epoch 8, lr: 0.0002694, train loss: 0.19019, val loss: 0.35765, balanced accuracy: 0.71133, (0.7113333333333334, {'HGSC': 0.5111111111111111, 'CC': 0.85, 'EC': 0.64, 'MC': 0.6666666666666666, 'LGSC': 0.8888888888888888})
# Wed Dec 13 08:56:37 2023 Epoch: 9
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7277777777777779
# Wed Dec 13 09:15:51 2023 Epoch 9, lr: 0.0002589, train loss: 0.18652, val loss: 0.29815, balanced accuracy: 0.72778, (0.7277777777777779, {'HGSC': 0.8444444444444444, 'CC': 0.75, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.4444444444444444})
# Wed Dec 13 09:15:51 2023 Epoch: 10
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7528888888888889
# Wed Dec 13 09:34:29 2023 Epoch 10, lr: 0.0002471, train loss: 0.17881, val loss: 0.27972, balanced accuracy: 0.75289, (0.7528888888888889, {'HGSC': 0.8, 'CC': 0.8, 'EC': 0.72, 'MC': 0.8888888888888888, 'LGSC': 0.5555555555555556})
# Wed Dec 13 09:34:29 2023 Epoch: 11
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6488888888888888
# Wed Dec 13 09:53:01 2023 Epoch 11, lr: 0.0002342, train loss: 0.17569, val loss: 0.32314, balanced accuracy: 0.64889, (0.6488888888888888, {'HGSC': 0.6222222222222222, 'CC': 0.8, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.2222222222222222})
# Wed Dec 13 09:53:01 2023 Epoch: 12
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.6904444444444444
# Wed Dec 13 10:11:21 2023 Epoch 12, lr: 0.0002203, train loss: 0.13210, val loss: 0.36803, balanced accuracy: 0.69044, (0.6904444444444444, {'HGSC': 0.6888888888888889, 'CC': 0.95, 'EC': 0.48, 'MC': 1.0, 'LGSC': 0.3333333333333333})
# Wed Dec 13 10:11:21 2023 Epoch: 13
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7173333333333334
# Wed Dec 13 10:29:41 2023 Epoch 13, lr: 0.0002055, train loss: 0.12115, val loss: 0.29212, balanced accuracy: 0.71733, (0.7173333333333333, {'HGSC': 0.7333333333333333, 'CC': 0.8, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.3333333333333333})
# Wed Dec 13 10:29:41 2023 Epoch: 14
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7355555555555555
# Wed Dec 13 10:48:05 2023 Epoch 14, lr: 0.0001901, train loss: 0.09659, val loss: 0.45033, balanced accuracy: 0.73556, (0.7355555555555555, {'HGSC': 0.7111111111111111, 'CC': 0.7, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 10:48:05 2023 Epoch: 15
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7393333333333334
# Wed Dec 13 11:06:34 2023 Epoch 15, lr: 0.0001743, train loss: 0.09563, val loss: 0.41438, balanced accuracy: 0.73933, (0.7393333333333334, {'HGSC': 0.6, 'CC': 0.75, 'EC': 0.68, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 11:06:34 2023 Epoch: 16
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7448888888888888
# Wed Dec 13 11:25:06 2023 Epoch 16, lr: 0.0001581, train loss: 0.09275, val loss: 0.39842, balanced accuracy: 0.74489, (0.7448888888888889, {'HGSC': 0.6888888888888889, 'CC': 0.8, 'EC': 0.68, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 11:25:06 2023 Epoch: 17
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7475555555555555
# Wed Dec 13 11:43:33 2023 Epoch 17, lr: 0.0001419, train loss: 0.07610, val loss: 0.33442, balanced accuracy: 0.74756, (0.7475555555555555, {'HGSC': 0.6222222222222222, 'CC': 0.8, 'EC': 0.76, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 11:43:33 2023 Epoch: 18
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7511111111111111
# Wed Dec 13 12:01:57 2023 Epoch 18, lr: 0.0001257, train loss: 0.06738, val loss: 0.29779, balanced accuracy: 0.75111, (0.7511111111111111, {'HGSC': 0.6888888888888889, 'CC': 0.8, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 12:01:57 2023 Epoch: 19
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7611111111111111
# Wed Dec 13 12:20:27 2023 Epoch 19, lr: 0.0001099, train loss: 0.04549, val loss: 0.26611, balanced accuracy: 0.76111, (0.7611111111111111, {'HGSC': 0.8, 'CC': 0.85, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 12:20:27 2023 Epoch: 20
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7653333333333334
# Wed Dec 13 12:39:10 2023 Epoch 20, lr: 0.0000945, train loss: 0.04280, val loss: 0.35862, balanced accuracy: 0.76533, (0.7653333333333332, {'HGSC': 0.7111111111111111, 'CC': 0.8, 'EC': 0.76, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 12:39:10 2023 Epoch: 21
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7251111111111112
# Wed Dec 13 12:57:34 2023 Epoch 21, lr: 0.0000797, train loss: 0.04536, val loss: 0.34711, balanced accuracy: 0.72511, (0.7251111111111112, {'HGSC': 0.6, 'CC': 0.75, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 12:57:35 2023 Epoch: 22
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7713333333333334
# Wed Dec 13 13:15:59 2023 Epoch 22, lr: 0.0000658, train loss: 0.04214, val loss: 0.32305, balanced accuracy: 0.77133, (0.7713333333333333, {'HGSC': 0.8, 'CC': 0.75, 'EC': 0.64, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 13:15:59 2023 Epoch: 23
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7457777777777779
# Wed Dec 13 13:34:11 2023 Epoch 23, lr: 0.0000529, train loss: 0.02986, val loss: 0.30533, balanced accuracy: 0.74578, (0.7457777777777779, {'HGSC': 0.7333333333333333, 'CC': 0.8, 'EC': 0.64, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 13:34:11 2023 Epoch: 24
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7653333333333333
# Wed Dec 13 13:52:42 2023 Epoch 24, lr: 0.0000411, train loss: 0.04128, val loss: 0.33984, balanced accuracy: 0.76533, (0.7653333333333333, {'HGSC': 0.6, 'CC': 0.8, 'EC': 0.76, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 13:52:42 2023 Epoch: 25
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7717777777777778
# Wed Dec 13 14:11:01 2023 Epoch 25, lr: 0.0000306, train loss: 0.04297, val loss: 0.28938, balanced accuracy: 0.77178, (0.7717777777777778, {'HGSC': 0.7333333333333333, 'CC': 0.85, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.5555555555555556})
# Wed Dec 13 14:11:01 2023 Epoch: 26
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7733333333333333
# Wed Dec 13 14:29:27 2023 Epoch 26, lr: 0.0000215, train loss: 0.02573, val loss: 0.30982, balanced accuracy: 0.77333, (0.7733333333333333, {'HGSC': 0.8, 'CC': 0.8, 'EC': 0.6, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 14:29:27 2023 Epoch: 27
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7802222222222223
# Wed Dec 13 14:48:02 2023 Epoch 27, lr: 0.0000139, train loss: 0.02723, val loss: 0.34015, balanced accuracy: 0.78022, (0.7802222222222223, {'HGSC': 0.7333333333333333, 'CC': 0.75, 'EC': 0.64, 'MC': 1.0, 'LGSC': 0.7777777777777778})
# Wed Dec 13 14:48:02 2023 Epoch: 28
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7651111111111111
# Wed Dec 13 15:06:27 2023 Epoch 28, lr: 0.0000079, train loss: 0.02547, val loss: 0.33323, balanced accuracy: 0.76511, (0.7651111111111111, {'HGSC': 0.6888888888888889, 'CC': 0.75, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 15:06:27 2023 Epoch: 29
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7468888888888888
# Wed Dec 13 15:24:52 2023 Epoch 29, lr: 0.0000035, train loss: 0.01970, val loss: 0.31555, balanced accuracy: 0.74689, (0.7468888888888888, {'HGSC': 0.7777777777777778, 'CC': 0.65, 'EC': 0.64, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# Wed Dec 13 15:24:52 2023 Epoch: 30
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#   0%|          | 0/108 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0.7806666666666666
# Wed Dec 13 15:43:16 2023 Epoch 30, lr: 0.0000009, train loss: 0.02770, val loss: 0.30736, balanced accuracy: 0.78067, (0.7806666666666666, {'HGSC': 0.6666666666666666, 'CC': 0.85, 'EC': 0.72, 'MC': 1.0, 'LGSC': 0.6666666666666666})
# comp metric max 0.8104444444444443
# CPU times: user 27min 19s, sys: 4min 28s, total: 31min 47s
# Wall time: 9h 21min 5s
