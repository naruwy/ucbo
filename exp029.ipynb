# %%
# !nvidia-smi
# Out:
# Fri Dec  1 14:16:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# prompt: CPUのコア数をしらべて
import os
os.cpu_count()
# Out:
# 2

# %%
class Config:
    name = "exp029" # 実験のたびにコピーしてここの名前を変えて実行するとoutputが別のファイルに保存される

    # Colab Env
    upload_from_colab = False
    api_path = "/content/drive/MyDrive/kaggle/kaggle.json"
    drive_path = "/content/drive/MyDrive/kaggle/ucbo"

DEBUG = False

# %%
import os
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime
import sys

# %%
COLAB = "google.colab" in sys.modules
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110683 sha256=f1e77cbcc2b861b4e84e48be8ce80ef3212c3d603fae4f74b6e61adfcc4b4757
#   Stored in directory: /root/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# Successfully installed kaggle-1.5.16

# %%
if COLAB:
    print("This environment is Google Colab")

    # mount
    from google.colab import drive
    if not os.path.isdir("/content/drive"):
        drive.mount('/content/drive')


    # use kaggle api (need kaggle token)
    f = open(Config.api_path, 'r')
    json_data = json.load(f)
    os.environ["KAGGLE_USERNAME"] = json_data["username"]
    os.environ["KAGGLE_KEY"] = json_data["key"]

    # set dirs
    DRIVE = Config.drive_path
    EXP = Config.name
    INPUT = os.path.join(DRIVE, "Input")
    OUTPUT = os.path.join(DRIVE, "Output")
    SCRIPT = os.path.join(DRIVE, "Script")
    OUTPUT_EXP = os.path.join(OUTPUT, EXP)
    # EXP_MODEL = os.path.join(OUTPUT_EXP, "model")
    # EXP_FIG = os.path.join(OUTPUT_EXP, "fig")
    # EXP_PREDS = os.path.join(OUTPUT_EXP, "preds")

    # make dirs
    for d in [INPUT, SCRIPT, OUTPUT, OUTPUT_EXP]:
        os.makedirs(d, exist_ok=True)

    # if not os.path.isfile(os.path.join(INPUT, "train.csv")):
    #     # load dataset
    #     ! kaggle competitions download -c UBC-OCEAN -p $INPUT
    #     unzip_file = os.path.join(INPUT, 'UBC-OCEAN.zip')
    #     ! unzip $unzip_file -d $INPUT
# Out:
# This environment is Google Colab
# Mounted at /content/drive

# %%
# %%time
if not DEBUG:
    # tmp fileに直接ダウンロードする
    TMP = '/content/tmp'
    INPUT = '/content/tmp'
    # !mkdir $TMP
    files = [
        'tyabanoamami/ucbo-colab-dataset', 'hmendonca/efficientnet-pytorch',
            #  'pjmathematician/ucbo-tiles-256-1', #'tyabanoamami/ucbo-clean-images',
            #  'pjmathematician/ucbo-tiles-256-2', 'pjmathematician/ucbo-tiles-256-3',
            #  'pjmathematician/ucbo-tiles-256-4', 'pjmathematician/ucbo-tiles-256-5',
        'jirkaborovec/tiles-of-cancer-2048px-scale-0-25'
            ]
    for f in files:
        # !kaggle datasets download -d $f -p $TMP
        t = f.split('/')[1]
        unzip_file = os.path.join(TMP, f'{t}.zip')
        unzip_file_ = TMP + '/' + t
        INPUT_ = INPUT + '/' + t
        ! unzip $unzip_file -d $unzip_file_
        # !mv $unzip_file_ $INPUT_
        # !rm -rf $unzip_file
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000345_22-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000346_23-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000347_24-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000348_25-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000357_7-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000358_8-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000359_9-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000360_10-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000361_11-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000362_12-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000363_13-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000364_14-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000365_15-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000366_16-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000367_17-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000368_18-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000369_19-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000370_20-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000371_21-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000372_22-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000373_23-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000374_24-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000375_25-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000385_8-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000386_9-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000387_10-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000388_11-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000389_12-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000390_13-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000391_14-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000392_15-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000393_16-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000394_17-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000395_18-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000396_19-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000415_11-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000416_12-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000417_13-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000418_14-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18813/000419_15-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000023_24-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000024_25-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000025_26-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000032_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000050_23-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000051_24-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000052_25-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000053_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000054_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000059_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000060_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000061_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000062_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000078_23-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000079_24-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000080_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000081_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000082_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000083_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000086_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000087_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000088_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000089_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000090_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000104_21-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000105_22-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000106_23-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000107_24-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000108_25-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000109_26-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000110_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000111_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000114_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000115_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000116_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000117_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000118_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000119_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000132_21-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000133_22-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000134_23-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000135_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000136_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000137_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000140_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000141_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000142_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000143_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000144_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000145_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000146_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000147_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000160_21-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000161_22-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000162_23-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000163_24-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000164_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000165_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000168_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000169_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000170_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000171_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000172_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000173_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000188_21-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000189_22-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000190_23-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000191_24-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000192_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000193_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000196_1-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000197_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000198_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000199_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000200_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000201_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000216_21-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000217_22-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000218_23-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000219_24-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000220_25-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000221_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000222_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000224_1-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000225_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000226_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000227_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000228_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000229_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000230_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000245_22-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000246_23-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000247_24-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000248_25-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000249_26-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000252_1-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000253_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000254_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000255_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000256_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000257_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000258_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000274_23-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000275_24-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000276_25-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000277_26-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000278_27-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000281_2-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000282_3-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000283_4-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000284_5-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000285_6-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000286_7-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000303_24-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000304_25-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000305_26-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000310_3-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000311_4-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000312_5-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000313_6-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000314_7-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000340_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18896/000341_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000000_1-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000001_2-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000004_5-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000005_6-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000006_7-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000007_8-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000022_23-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000023_24-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000024_25-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000025_26-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000026_27-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000027_28-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000028_29-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000030_1-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000031_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000032_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000033_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000034_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000035_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000036_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000037_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000051_22-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000052_23-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000053_24-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000054_25-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000055_26-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000056_27-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000057_28-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000058_29-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000060_1-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000061_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000062_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000063_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000064_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000065_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000066_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000067_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000081_22-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000082_23-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000083_24-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000084_25-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000085_26-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000086_27-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000087_28-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000088_29-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000089_30-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000090_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000091_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000092_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000093_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000094_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000095_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000096_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000097_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000111_22-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000112_23-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000113_24-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000114_25-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000115_26-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000116_27-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000117_28-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000118_29-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000119_30-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000120_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000121_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000122_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000123_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000124_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000125_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000126_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000127_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000141_22-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000142_23-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000143_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000144_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000145_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000146_27-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000147_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000148_29-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000149_30-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000150_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000151_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000152_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000153_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000154_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000155_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000156_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000157_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000171_22-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000172_23-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000173_24-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000174_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000175_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000176_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000177_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000178_29-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000179_30-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000180_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000181_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000182_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000183_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000184_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000185_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000186_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000187_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000201_22-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000202_23-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000203_24-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000204_25-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000205_26-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000206_27-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000207_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000208_29-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000209_30-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000210_1-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000211_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000212_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000213_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000214_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000215_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000216_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000217_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000231_22-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000232_23-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000233_24-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000234_25-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000235_26-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000236_27-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000237_28-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000238_29-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000239_30-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000240_1-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000241_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000242_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000243_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000244_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000245_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000246_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000247_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000261_22-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000262_23-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000263_24-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000264_25-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000265_26-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000266_27-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000267_28-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000268_29-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000269_30-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000271_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000272_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000273_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000274_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000275_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000276_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000277_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000292_23-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000293_24-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000294_25-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000295_26-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000296_27-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000297_28-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000298_29-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000299_30-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18914/000307_8-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000004_5-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000008_9-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000009_10-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000010_11-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000011_12-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000012_13-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000015_1-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000016_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000017_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000018_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000019_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000020_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000023_9-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000024_10-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000025_11-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000026_12-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000027_13-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000030_1-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000031_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000032_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000033_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000034_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000035_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000036_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000037_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000038_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000039_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000040_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000041_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000042_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000043_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000044_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000045_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000046_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000047_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000048_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000049_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000050_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000051_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000052_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000053_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000054_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000055_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000056_12-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000057_13-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000058_14-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000059_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000060_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000061_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000062_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000063_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000064_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000065_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000066_7-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000067_8-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000068_9-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000069_10-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000070_11-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000071_12-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000072_13-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000073_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000074_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000075_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000076_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000077_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000078_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000079_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000080_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000081_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000082_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000083_9-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000084_10-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000085_11-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000086_12-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000087_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000088_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000089_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000090_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000091_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000092_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000093_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000094_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000095_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000096_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000097_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000098_9-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000099_10-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000100_11-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000101_12-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000102_13-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000103_14-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000105_1-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000106_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000107_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000108_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000109_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000110_6-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000111_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000112_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000113_9-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000114_10-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000115_11-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000116_12-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000117_13-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000118_14-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000120_1-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000121_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000122_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000123_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000124_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000125_6-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000126_7-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000127_8-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000128_9-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000129_10-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000130_11-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000131_12-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000132_13-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000133_14-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000135_1-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000136_2-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000137_3-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000138_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000139_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000140_6-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000141_7-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000142_8-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000143_9-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000144_10-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000145_11-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000146_12-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000147_13-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000148_14-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000150_1-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000151_2-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000152_3-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000153_4-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000154_5-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000155_6-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000156_7-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000157_8-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000158_9-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000159_10-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000160_11-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000161_12-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000162_13-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000163_14-11.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000165_1-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000166_2-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000167_3-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000168_4-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000169_5-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000170_6-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000171_7-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000172_8-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000173_9-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000174_10-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000175_11-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000176_12-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000177_13-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000178_14-12.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000180_1-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000181_2-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000182_3-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000183_4-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000184_5-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000185_6-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000186_7-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000187_8-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000188_9-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000189_10-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000190_11-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000191_12-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000192_13-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000193_14-13.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000195_1-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000196_2-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000197_3-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000198_4-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000199_5-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000200_6-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000201_7-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000202_8-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000203_9-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000204_10-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000205_11-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000206_12-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000207_13-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000208_14-14.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000211_2-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000212_3-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000213_4-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000214_5-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000215_6-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000216_7-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000217_8-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000218_9-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000219_10-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000220_11-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000221_12-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000222_13-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000223_14-15.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000227_3-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000228_4-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000229_5-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000230_6-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000231_7-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000232_8-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000233_9-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000234_10-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000235_11-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000236_12-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000237_13-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000238_14-16.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000245_6-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000246_7-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000247_8-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000248_9-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000249_10-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000250_11-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000251_12-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000252_13-17.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000261_7-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000262_8-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/18981/000263_9-18.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000004_5-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000005_6-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000006_7-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000010_2-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000011_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000012_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000013_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000014_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000015_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000016_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000019_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000020_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000021_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/19030/000022_5-3.png
# ...
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000138_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000139_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000140_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000141_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000147_24-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000148_25-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000149_26-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000150_27-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000151_28-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000152_29-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000153_30-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000156_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000157_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000158_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000159_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000160_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000161_7-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000162_8-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000167_13-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000168_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000169_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000170_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000171_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000172_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000173_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000179_25-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000180_26-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000181_27-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000182_28-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000183_29-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000184_30-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000185_31-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000190_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000191_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000192_7-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000193_8-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000202_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000203_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000204_19-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000213_28-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000214_29-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000215_30-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000216_31-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000223_7-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000224_8-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000234_18-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000235_19-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20670/000246_30-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000015_16-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000016_17-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000017_18-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000018_19-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000022_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000023_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000024_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000025_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000035_16-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000036_17-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000037_18-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000038_19-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000039_20-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000042_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000043_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000044_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000045_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000054_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000055_16-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000056_17-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000057_18-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000058_19-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000059_20-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000061_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000062_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000063_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000064_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000065_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000074_15-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000075_16-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000076_17-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000077_18-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000078_19-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000079_20-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000080_1-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000081_2-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000082_3-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000083_4-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000084_5-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000085_6-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000093_14-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000094_15-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000095_16-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000096_17-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000097_18-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000098_19-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000099_20-5.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000100_1-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000101_2-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000102_3-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000103_4-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000104_5-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000105_6-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000113_14-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000114_15-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000115_16-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000116_17-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000117_18-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000118_19-6.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000120_1-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000121_2-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000122_3-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000123_4-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000124_5-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000125_6-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000134_15-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000135_16-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000136_17-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000137_18-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000138_19-7.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000140_1-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000141_2-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000142_3-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000143_4-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000144_5-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000155_16-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000156_17-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000157_18-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000158_19-8.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000161_2-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000162_3-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000163_4-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000164_5-9.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000183_4-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20858/000184_5-10.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000002_3-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000003_4-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000004_5-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000005_6-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000006_7-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000007_8-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000008_9-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000009_10-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000010_11-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000011_12-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000012_13-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000013_14-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000014_15-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000015_16-1.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000021_3-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000022_4-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000023_5-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000024_6-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000025_7-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000026_8-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000027_9-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000028_10-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000029_11-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000030_12-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000031_13-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000032_14-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000033_15-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000034_16-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000035_17-2.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000039_2-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000040_3-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000041_4-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000042_5-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000043_6-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000044_7-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000045_8-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000046_9-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000047_10-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000048_11-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000049_12-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000050_13-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000051_14-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000052_15-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000053_16-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000054_17-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000055_18-3.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000057_1-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000058_2-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000059_3-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000060_4-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000061_5-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000062_6-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000063_7-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000064_8-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000065_9-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000066_10-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000067_11-4.png
#   inflating: /content/tmp/tiles-of-cancer-2048px-scale-0-25/20882/000068_12-4.png

# %% [markdown]
# # Library

# %%
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# !pip install timm

# %%
import os
import sys
sys.path = [
    os.path.join(INPUT, 'efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master'),
] + sys.path

# %%
import time
import skimage.io
import numpy as np
import pandas as pd
import cv2
import PIL.Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler, SequentialSampler
from warmup_scheduler import GradualWarmupScheduler
from efficientnet_pytorch import model as enet
import albumentations
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from tqdm.notebook import tqdm
from sklearn.metrics import balanced_accuracy_score
import timm

# %%
# df = pd.read_csv('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/train.csv')
# df[df.image_id==int(folders[1].split('/')[-1])].is_tma.values
# from glob import glob
# folders = glob('/content/drive/MyDrive/kaggle/ucbo/Input/tiles-of-cancer-2048px-scale-0-25/*')
# for f in sorted(folders, key=lambda x: int(x.split('/')[-1]) if x.split('/')[-1]!='train.csv' else 999999)[:-1]:
#     tma=False
#     if df[df.image_id==int(f.split('/')[-1])].is_tma.values[0]:
#         tma=True
#     print(f.split('/')[-1], len(glob(f+'/*png')), tma)

# %% [markdown]
# # Config

# %%
data_dir = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
df_train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
image_folder = os.path.join(data_dir, 'train_images')
labels = ['CC', 'EC', 'HGSC', 'LGSC', 'MC', 'Other'] #df_train['label'].unique().tolist() + ['Other']
l2n = {v: k for k, v in enumerate(labels)}
n2l = {k: v for k, v in enumerate(labels)}

kernel_type = Config.name

enet_type = 'efficientnet_b0'
fold = 0
tile_size = 512
image_size = 512
n_tiles = 4 if DEBUG else 9
batch_size = 2
num_workers = os.cpu_count()
out_dim = 5
init_lr = 3e-4
warmup_factor = 10

warmup_epo = 1
n_epochs = 1 if DEBUG else 20
df_train = df_train.sample(100).reset_index(drop=True) if DEBUG else df_train

device = torch.device('cuda')

print(image_folder)

import random
def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_torch()

# %% [markdown]
# # Create Folds

# %%
skf = StratifiedKFold(5, shuffle=True, random_state=42)
df_train['fold'] = -1
for i, (train_idx, valid_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[valid_idx, 'fold'] = i
# df_train.head()

# %%
def get_image_path(image_id:int):
    # if 4 <= image_id <= 15188:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-1')
    # elif 15209 <= image_id <= 30515:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-2')
    # elif 30539 <= image_id <= 38687:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-3')
    # elif 38849 <= image_id <= 65300:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-4')
    # elif 65371 <= image_id <= 65533:
    #     path = os.path.join(INPUT, 'ucbo-tiles-256-5')
    path = os.path.join(INPUT, 'tiles-of-cancer-2048px-scale-0-25')
    return os.path.join(path, str(image_id))

df_train['tile_path'] = df_train['image_id'].apply(lambda x: get_image_path(x))

# df_train['total_tiles'] = df_train['tile_path'].apply(lambda x: len(os.listdir(x)))
# df_train.head()

# train['clean_tiles'] = train['image_id'].apply(lambda x: len(d[x]))/train['total_tiles']
# train.head()

# %% [markdown]
# # Model

# %%
# prompt: class enetv2(nn.Module):     def __init__(self, backbone, out_dim):         super(enetv2, self).__init__()         self.enet = enet.EfficientNet.from_name(backbone)         self.enet.load_state_dict(torch.load(pretrained_model[backbone]))          self.myfc = nn.Linear(self.enet._fc.in_features, out_dim)         self.enet._fc = nn.Identity()      def extract(self, x):         return self.enet(x)      def forward(self, x):         x = self.extract(x)         x = self.myfc(x)         return xこのモデルをtimmを使って書き直してください
class GeM(nn.Module):
    def __init__(self, p=3, eps=1e-6):
        super(GeM, self).__init__()
        self.p = nn.Parameter(torch.ones(1)*p)
        self.eps = eps

    def forward(self, x):
        return self.gem(x, p=self.p, eps=self.eps)

    def gem(self, x, p=3, eps=1e-6):
        return F.avg_pool2d(x.clamp(min=eps).pow(p), (x.size(-2), x.size(-1))).pow(1./p)

    def __repr__(self):
        return self.__class__.__name__ + \
                '(' + 'p=' + '{:.4f}'.format(self.p.data.tolist()[0]) + \
                ', ' + 'eps=' + str(self.eps) + ')'


class enetv2(nn.Module):
    def __init__(self, backbone, out_dim):
        super(enetv2, self).__init__()
        self.enet = timm.create_model(backbone, pretrained=True)
        self.myfc = nn.Linear(self.enet.classifier.in_features, out_dim)
        self.enet.classifier = nn.Identity()
        self.enet.global_pool = nn.Identity()
        self.pooling = GeM()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
        x = self.pooling(x).flatten(1)
        x = self.myfc(x)

        return x

# %%
# model = enetv2('efficientnet_b0', 6)
# model = timm.create_model('efficientnet_b0', pretrained=True)
# model.__dict__['default_cfg']

# %% [markdown]
# # Dataset

# %%
import joblib
good_images = joblib.load(os.path.join(OUTPUT, 'bw_checker/good_images.pkl'))

# %%
def get_tiles(paths):
    ret = []
    for path in paths:
        # PNGファイルを読み込み
        image = PIL.Image.open(path)

        # Pillow ImageオブジェクトをNumPy配列に変換
        image_array = np.array(image)
        ret.append(image_array)
    return ret


class PANDADataset(Dataset):
    def __init__(self,
                 df,
                 image_size,
                 n_tiles=n_tiles,
                 tile_mode=0,
                 rand=False,
                 transform=None,
                ):

        self.df = df.reset_index(drop=True)
        self.image_size = image_size
        self.n_tiles = n_tiles
        self.tile_mode = tile_mode
        self.rand = rand
        self.transform = transform

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]
        img_id = row.image_id


        try:
            tiles = good_images[img_id]
        except:
            files = os.listdir(row.tile_path)
            tiles = [row.tile_path + f'/{e}' for e in files]
        # if DEBUG:
        #     tiles = [t.replace('/content/tmp', INPUT) for t in tiles]
        n_imgs = len(tiles)
        tiles = get_tiles(tiles)


        if self.rand:
            idxes = np.random.choice(list(range(self.n_tiles)), self.n_tiles, replace=False)
        else:
            idxes = list(range(self.n_tiles))

        n_row_tiles = int(np.sqrt(self.n_tiles))
        images = np.zeros((image_size * n_row_tiles, image_size * n_row_tiles, 3))
        for h in range(n_row_tiles):
            for w in range(n_row_tiles):
                i = h * n_row_tiles + w

                # fill all tiles(exp014)
                try:
                    this_img = tiles[idxes[i%n_imgs]]
                except:
                    this_img = np.ones((self.image_size, self.image_size, 3)).astype(np.uint8) * 255
                # if len(tiles) > idxes[i]:
                #     this_img = tiles[idxes[i]]
                # else:
                #
                this_img = 255 - this_img
                if self.transform is not None:
                    this_img = self.transform(image=this_img)['image']
                h1 = h * image_size
                w1 = w * image_size
                images[h1:h1+image_size, w1:w1+image_size] = this_img

        # if self.transform is not None:
        #     images = self.transform(image=images)['image']
        images = images.astype(np.float32)
        # images /= 255
        images = images.transpose(2, 0, 1)

        # label = np.zeros(out_dim).astype(np.float32)
        # label[l2n[row.label]] = 1.

        #label smoothing(exp006)
        eps = 0.05
        label = np.ones(out_dim).astype(np.float32) * eps/out_dim
        label[l2n[row.label]] += (1. - eps)

        return torch.tensor(images), torch.tensor(label)

# %% [markdown]
# # Augmentations

# %%
transforms_train = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406], # 上のimages /= 255に注意
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    albumentations.Transpose(p=0.5),
    albumentations.VerticalFlip(p=0.5),
    albumentations.HorizontalFlip(p=0.5),
])
transforms_val = albumentations.Compose([
    albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
                max_pixel_value=255.0,
                p=1.0),
    ])

# efficientnetb0
# 'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),

# %%
# dataset_show = PANDADataset(df_train, image_size, n_tiles, 0, transform=transforms_train)
# from pylab import rcParams
# rcParams['figure.figsize'] = 20,10
# for i in range(2):
#     f, axarr = plt.subplots(1,5)
#     for p in range(5):
#         idx = np.random.randint(0, len(dataset_show))
#         img, label = dataset_show[idx]
#         axarr[p].imshow(1. - img.transpose(0, 1).transpose(1,2).squeeze())
#         axarr[p].set_title(label)

# %% [markdown]
# # Loss

# %%
criterion = nn.BCEWithLogitsLoss()
# criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Train and Val

# %%
def train_epoch(loader, optimizer):

    model.train()
    train_loss = []
    bar = tqdm(loader)
    for (data, target) in bar:

        data, target = data.to(device), target.to(device)
        loss_func = criterion
        optimizer.zero_grad()
        logits = model(data)
        loss = loss_func(logits, target)
        loss.backward()
        optimizer.step()

        loss_np = loss.detach().cpu().numpy()
        train_loss.append(loss_np)
        smooth_loss = sum(train_loss[-100:]) / min(len(train_loss), 100)
        bar.set_description('loss: %.5f, smth: %.5f' % (loss_np, smooth_loss))
    return train_loss


def val_epoch(loader, get_output=False):

    model.eval()
    val_loss = []
    LOGITS = []
    PREDS = []
    TARGETS = []

    with torch.no_grad():
        for (data, target) in tqdm(loader):
            data, target = data.to(device), target.to(device)
            logits = model(data)

            loss = criterion(logits, target)

            pred = logits.sigmoid().detach()
            LOGITS.append(logits)
            PREDS.append(pred)
            TARGETS.append(target)

            val_loss.append(loss.detach().cpu().numpy())
        val_loss = np.mean(val_loss)

    LOGITS = torch.cat(LOGITS).cpu().numpy()
    PREDS = torch.cat(PREDS).cpu().numpy()
    TARGETS = torch.cat(TARGETS).cpu().numpy()
#     acc = (PREDS == TARGETS).mean() * 100.
    comp_metric = balanced_accuracy_score(TARGETS.argmax(1), PREDS.argmax(1))
    print(comp_metric)

#     qwk = cohen_kappa_score(PREDS, TARGETS, weights='quadratic')
#     qwk_k = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'karolinska'], df_valid[df_valid['data_provider'] == 'karolinska'].isup_grade.values, weights='quadratic')
#     qwk_r = cohen_kappa_score(PREDS[df_valid['data_provider'] == 'radboud'], df_valid[df_valid['data_provider'] == 'radboud'].isup_grade.values, weights='quadratic')
#     print('qwk', qwk, 'qwk_k', qwk_k, 'qwk_r', qwk_r)

    if get_output:
        return LOGITS
    else:
        return val_loss, comp_metric, PREDS

# %% [markdown]
# # Create Dataloader & Model & Optimizer

# %%
train_idx = np.where((df_train['fold'] != fold))[0]
valid_idx = np.where((df_train['fold'] == fold))[0]

df_this  = df_train.loc[train_idx]
df_valid = df_train.loc[valid_idx]

dataset_train = PANDADataset(df_this , image_size, n_tiles, transform=transforms_train)
dataset_valid = PANDADataset(df_valid, image_size, n_tiles, transform=transforms_val)

train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, sampler=RandomSampler(dataset_train), num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset_valid, batch_size=batch_size, sampler=SequentialSampler(dataset_valid), num_workers=num_workers)

model = enetv2(enet_type, out_dim=out_dim)
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr=init_lr/warmup_factor)
scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs-warmup_epo)
scheduler = GradualWarmupScheduler(optimizer, multiplier=warmup_factor, total_epoch=warmup_epo, after_scheduler=scheduler_cosine)

print(len(dataset_train), len(dataset_valid))

# %% [markdown]
# # Run Training

# %%
# %%time
comp_metric_max = 0.
best_file = os.path.join(OUTPUT_EXP, f'{kernel_type}_best_fold{fold}.pth')
for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)
    scheduler.step(epoch-1)

    train_loss = train_epoch(train_loader, optimizer)
    val_loss, comp_metric, oof_preds = val_epoch(valid_loader)

    content = time.ctime() + ' ' + f'Epoch {epoch}, lr: {optimizer.param_groups[0]["lr"]:.7f}, train loss: {np.mean(train_loss):.5f}, val loss: {np.mean(val_loss):.5f}, balanced accuracy: {(comp_metric):.5f}'
    print(content)
    with open(os.path.join(OUTPUT_EXP, f'log_{kernel_type}.txt'), 'a') as appender:
        appender.write(content + '\n')

    if comp_metric > comp_metric_max:
        print('score2 ({:.6f} --> {:.6f}).  Saving model ...'.format(comp_metric_max, comp_metric))
        torch.save(model.state_dict(), best_file)
        np.save(os.path.join(OUTPUT_EXP, f'oof_preds_best_fold{fold}.npy'), oof_preds)
        comp_metric_max = comp_metric

torch.save(model.state_dict(), os.path.join(OUTPUT_EXP, f'{kernel_type}_final_fold{fold}.pth'))
np.save(os.path.join(OUTPUT_EXP, f'oof_preds_final_fold{fold}.npy'), oof_preds)
print(f'comp metric max {comp_metric_max}')
